# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from PIL import Image
import warnings
import os , io
import urllib
import cv2
warnings.filterwarnings("ignore")

# os.environ["KMP_DUPLICATE_LIB_OK"]="True"
# %matplotlib inline

import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# %%
#데이터 불러오기
df = pd.read_pickle("./result.pkl")

# %%
# 제목 특수문자 제거 , 중복제거
df["title"] = df["title"].str.replace(pat=r'[^\w]', repl=r' ', regex=True)
df = df.drop_duplicates(['title'],keep='last')

# %%
df.head()

# %%
#에러 데이터 분류 및 이미지 전처리
newI = []
undefine = []
transformationForCNNInput = transforms.Compose([transforms.Resize((224,224))])
for i , imagePath in enumerate(df.imgAdr.values):
    try:
        fd = urllib.request.urlopen(imagePath)
        image_file = io.BytesIO(fd.read())
        im = Image.open(image_file)
        newI.append(transformationForCNNInput(im))
    except Exception as e:
        undefine.append(i)
        
df_new = df.drop(undefine) # 주소로 얻은 이미지가 없을 경우 제거

# %%
df_new = df.drop(undefine).reset_index(drop=True)

# %%
import torch
from tqdm import tqdm
from torchvision import models

# for this prototype we use no gpu, cuda= False and as model resnet18 to obtain feature vectors

class Img2VecResnet18():
    def __init__(self): 
        
        self.device = torch.device("cpu")
        self.numberFeatures = 2048
        self.modelName = "resnet-50"
        self.model, self.featureLayer = self.getFeatureLayer()
        self.model = self.model.to(self.device)
        self.model.eval()
        self.toTensor = transforms.ToTensor()
        
        # normalize the resized images as expected by resnet18
        # [0.485, 0.456, 0.406] --> normalized mean value of ImageNet, [0.229, 0.224, 0.225] std of ImageNet
        self.normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        
    def getVec(self, img):
        image = self.normalize(self.toTensor(img)).unsqueeze(0).to(self.device)
        embedding = torch.zeros(1, self.numberFeatures, 1, 1)
        
        # _ in-place 연산자
        def copyData(m, i, o): embedding.copy_(o.data)

        h = self.featureLayer.register_forward_hook(copyData)
        self.model(image)
        h.remove()

        return embedding.numpy()[0, :, 0, 0]

    def getFeatureLayer(self):
        
        cnnModel = models.resnet50(pretrained=True)
        layer = cnnModel._modules.get('avgpool')
        self.layer_output_size = 2048
        
        return cnnModel, layer
        

# generate vectors for all the images in the set
img2vec = Img2VecResnet18() 

allVectors = {}
print("Converting images to feature vectors:")
for i,image in tqdm(enumerate(newI)):
    vec = img2vec.getVec(image)
    allVectors[df_new.title.values[i]] = vec
    I.close()
# Out:
# 0it [00:00, ?it/s]
# Converting images to feature vectors:
# 1752it [06:06,  4.78it/s]

# %%
len(allVectors)
# Out:
# 1752

# %%
# #
# file = open('imgVectors','wb')
# pickle.dump(allVectors,file)
# file.close()

# %%
file=open("imgVectors","rb")
content=pickle.load(file)
content
# Out:
# {'김경재  박근혜 구하기   삼성 출연금 8천억  노무현이 해먹었다': array([0.406081  , 1.182641  , 0.6384161 , ..., 0.71324694, 0.16910838,
#         0.01235447], dtype=float32),
#  '가수 최정철 일병   나미  모자 母子 가 한 무대에서 노래': array([0.01629067, 0.4758948 , 0.18863228, ..., 0.2960348 , 0.06336597,
#         0.8393159 ], dtype=float32),
#  '주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나 ': array([0.03419235, 0.8358128 , 0.49980032, ..., 0.31874302, 0.09653488,
#         0.4902933 ], dtype=float32),
#  '트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다': array([0.50568765, 0.34878537, 0.62028545, ..., 0.19751611, 0.41032597,
#         0.2745127 ], dtype=float32),
#  ' 남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑 ': array([0.04391704, 1.5924565 , 0.519614  , ..., 0.12465615, 0.26964918,
#         0.07469084], dtype=float32),
#  '불여우 따라간 한우마을 묻지마 관광': array([0.17433497, 0.64102197, 0.38046566, ..., 0.08048116, 0.42614973,
#         0.01360089], dtype=float32),
#  ' 유엔참전용사 추모 음악회  국악인 김영임   경기민요 메들리 Young Im Kim': array([0.00263955, 0.28299654, 0.93573743, ..., 0.3050802 , 0.55059856,
#         0.07752004], dtype=float32),
#  '어머니뻘 시민 짓밟고 패륜적 욕설 퍼붇는 폭력범을 뻔히 보며 방관': array([0.14155838, 0.26797378, 0.35565296, ..., 0.18109918, 0.26674056,
#         0.31173226], dtype=float32),
#  '여군 헌병 순찰소대장 위풍당당 Female MP Platoon Leader on Patrol': array([0.32143086, 0.43563426, 0.22570182, ..., 0.04293658, 0.04784538,
#         0.17316522], dtype=float32),
#  '김동규  10월의 어느 멋진 날에  Bar  Kim Dong Kyu  A Wonderful Day in October ': array([0.11357098, 0.11407584, 1.1574574 , ..., 0.31169814, 0.24835591,
#         0.09659135], dtype=float32),
#  ' ROTC 음악회  테너 김호중  베이스 권순동  향수  정지용 시 김희갑 곡 ': array([0.12212935, 0.32806498, 1.2238154 , ..., 0.13812375, 0.4425327 ,
#         0.14378089], dtype=float32),
#  ' 9사단 앞 땅굴 의혹 현장답사  15m 땅밑에 무슨 농수로 ': array([0.06235928, 0.6785387 , 0.23128492, ..., 0.28261468, 0.44285503,
#         0.17734298], dtype=float32),
#  '이명박 대통령  방아개비 절해도 노무현 유족들 외면': array([0.01224163, 0.62167466, 0.24616401, ..., 0.13170752, 0.03518857,
#         0.00640663], dtype=float32),
#  '김진태 후보 자갈치시장 방문 중 가게 이모들 표정': array([0.2025283 , 0.79368   , 0.12259719, ..., 0.01914739, 0.03204395,
#         0.38370398], dtype=float32),
#  '김경재 총재   탄핵광풍 배후 JTBC 회장 홍석현을 만났더니   ': array([0.16156627, 1.9075196 , 0.3372078 , ..., 0.05135471, 0.12212413,
#         0.22156131], dtype=float32),
#  ' 눈물 젖은 팽목항  인상착의 듣고 곧장 신원확신한 어머니는   ': array([0.02949031, 0.56474644, 0.414524  , ..., 0.42844585, 0.29214963,
#         0.47920278], dtype=float32),
#  ' 원로 언론인 시평  두고 보세요  박근혜한테 집니다': array([0.15434097, 0.05343762, 0.05734976, ..., 0.05059418, 0.01495416,
#         0.21030462], dtype=float32),
#  '광주 임산부 최미애씨 학살 목격자 증언 극적 반전  공수부대 누명 벗다': array([0.12546149, 0.04188983, 0.06679343, ..., 0.06353023, 0.04522591,
#         0.34174246], dtype=float32),
#  '변희재   상습조작 손석희가 신뢰도 1위  나라 망한 증거': array([0.04061224, 1.0973701 , 0.08198502, ..., 0.28976852, 0.20939153,
#         0.2306889 ], dtype=float32),
#  ' 김동길 용인 5  김대중 때문에 호남사람 좋아하지 못하게 됐다': array([0.03637639, 0.80143696, 0.22528866, ..., 0.03524391, 0.08377466,
#         0.09355637], dtype=float32),
#  '정의구현사제단 축출 특공대 인천 상륙  3    주교 보고 빨갱이래  폭력 불사 위협': array([0.12215389, 1.1044359 , 0.15238541, ..., 0.12804712, 0.31576934,
#         0.01220674], dtype=float32),
#  '대학원생 한근형   판검사 5 18가산점 실태 은폐 및 김영삼 이명박 이적 통박': array([0.38996637, 1.9541398 , 0.51334363, ..., 0.24777095, 0.3028273 ,
#         0.16331843], dtype=float32),
#  'JTBC 손석희 논란의 핵심은 바로 이것   ': array([9.1038316e-02, 2.3764760e+00, 4.1765940e-01, ..., 9.5835455e-02,
#         1.5532164e-01, 1.6604313e-03], dtype=float32),
#  '프로포폴 중독 논란   김제동의 처세술': array([1.1105348 , 2.3023734 , 2.4636996 , ..., 0.16896428, 0.54598624,
#         0.81727886], dtype=float32),
#  '뻔뻔한 김혜수  feat  강지환 ': array([0.21627533, 0.3841424 , 0.98241484, ..., 0.05275306, 0.3532391 ,
#         0.71272916], dtype=float32),
#  ' 단독  김부선  이재명과 밀회 장소 최초 공개': array([0.01309298, 1.0313793 , 0.24992187, ..., 0.05350102, 0.23086813,
#         0.01522282], dtype=float32),
#  '고준희 버닝썬 접대 논란   ': array([0.4584752 , 0.85498273, 0.9747419 , ..., 0.06365532, 0.23718199,
#         0.29475114], dtype=float32),
#  ' 충격단독  김건모 성폭행 의혹   ': array([0.5454144 , 0.88035643, 0.3848279 , ..., 0.11437487, 0.9112768 ,
#         0.35962197], dtype=float32),
#  ' 단독  김건모 결혼 연기 진짜 이유   ': array([0.13728306, 2.2120929 , 0.4842252 , ..., 0.20527782, 0.16561966,
#         0.02453965], dtype=float32),
#  ' 충격연예  정준영과 트와이스 무슨 관계 ': array([0.18376763, 1.5760663 , 0.76040757, ..., 0.0838507 , 0.23487541,
#         0.21945296], dtype=float32),
#  ' 단독  아무도 몰랐던 임블리의 충격적 과거 폭로': array([0.36049178, 0.70211214, 0.96392107, ..., 0.292023  , 0.939981  ,
#         0.22039554], dtype=float32),
#  ' 충격  유재석 첫 단독 기자회견 이유': array([0.37776542, 2.3295643 , 0.4519582 , ..., 0.22146879, 0.31504875,
#         0.17226781], dtype=float32),
#  ' 단독공개  김건모 피해자 심경고백  또다른 피해자 등장    ': array([0.13111518, 1.1686836 , 0.6177856 , ..., 0.04034554, 0.18595894,
#         0.17582853], dtype=float32),
#  '중국 권력 암투 최후의 결전': array([0.36870348, 1.0996348 , 1.6758289 , ..., 0.00956019, 0.17799567,
#         0.22753988], dtype=float32),
#  ' 단독  하꼬방 가족회사 욕설왕 손석희': array([0.23925851, 1.0609709 , 0.6741183 , ..., 0.08997864, 0.5407166 ,
#         0.32882178], dtype=float32),
#  ' 김경재 격정토로  김대중은 우파인 한화갑과 나를   ': array([0.41106734, 2.0171525 , 0.7349209 , ..., 0.04566189, 0.16898964,
#         0.13525255], dtype=float32),
#  ' 충격단독  홍진영 언니 버닝썬 연결고리  추미애 1억원 비만 클리닉 의혹 ': array([0.084257  , 1.0622039 , 0.6197837 , ..., 0.1379327 , 0.20475411,
#         0.03036064], dtype=float32),
#  '구혜선 안재현 이혼 진짜 이유  Feat  문보미 ': array([0.03985596, 2.3036363 , 0.38237742, ..., 0.18761073, 0.18827686,
#         0.07421961], dtype=float32),
#  '충격    조국과 이보영의 관계   ': array([0.09769487, 1.8880469 , 0.97132003, ..., 0.07207141, 0.38776726,
#         0.20180073], dtype=float32),
#  '윤지오 충격영상 전격공개   ': array([0.20020214, 1.5202297 , 0.33573663, ..., 0.01383033, 0.27949566,
#         0.17380017], dtype=float32),
#  ' 충격단독  김건모 추가폭로    또다른 피해자 격정 고발   ': array([0.0211997 , 2.2851079 , 0.29211205, ..., 0.13376494, 0.75939864,
#         0.2423745 ], dtype=float32),
#  '최초공개    6억 재산 림종석 딸 명품녀 림동아 집중분석   ': array([0.07076018, 1.7088375 , 0.30808502, ..., 0.05282291, 0.41082183,
#         0.2954116 ], dtype=float32),
#  '기자회견에서 드러난 조국 결정적 실수': array([0.09465632, 1.5101048 , 1.5049    , ..., 0.09022527, 0.33146167,
#         0.16306567], dtype=float32),
#  '이정현의원  뜨거운 가슴의 피토하는 질의  지금은 국가재난 상태다   특별방송 이정현의원국회 대정부질의 2020 03 04': array([0.45491126, 1.0871087 , 0.7124004 , ..., 0.00897333, 0.201489  ,
#         0.02806811], dtype=float32),
#  '법정을 울음바다로 만든 박근혜대통령 최후진술  염순태 대표 특별대담 ': array([0.03560335, 1.1050088 , 0.3382763 , ..., 0.12066413, 0.14178836,
#         0.06297145], dtype=float32),
#  '문대통령 탄핵사유 쌓이고 있다 with 박찬종 변호사  특별대담 ': array([0.1119934 , 2.1150568 , 0.6931042 , ..., 0.47749987, 0.06631823,
#         0.13102716], dtype=float32),
#  '고영태는 누구인가   7  박대통령탄핵의 거짓과 진실 특별방송 ': array([0.10277119, 1.647284  , 0.52699834, ..., 0.12607817, 0.15720716,
#         0.15386844], dtype=float32),
#  '5 18 북한군개입 주장은 18년간 연구 조사한 결과다 with 지만원 박사  특별대담 ': array([0.10907558, 1.3365692 , 0.6353178 , ..., 0.07045458, 0.09068858,
#         0.18936858], dtype=float32),
#  '박근혜대통령 탄핵과 재판의 거짓과 진실  서정욱편': array([0.13610281, 0.7562818 , 0.3407548 , ..., 0.00395718, 0.17031133,
#         0.08091444], dtype=float32),
#  '북한군사력 전면해부   with 김정봉교수  특별대담 ': array([0.16334398, 2.0580056 , 0.57070446, ..., 0.20352116, 0.3166792 ,
#         0.10406843], dtype=float32),
#  ' 김문수 특별대담   김무성 출당  논쟁': array([0.21434401, 2.1440742 , 0.7238762 , ..., 0.00612084, 0.14697087,
#         0.2309444 ], dtype=float32),
#  ' 박찬종변호사 특별대담  문대통령 탄핵사유  계속 쌓이고 있다': array([0.05527062, 1.7921765 , 0.4845048 , ..., 0.12489658, 0.16784629,
#         0.01872843], dtype=float32),
#  '박근혜대통령 탄핵의 거짓과 진실 특별방송  우종창기자편': array([0.04797725, 1.1779003 , 0.28048834, ..., 0.06071516, 0.03345254,
#         0.08691364], dtype=float32),
#  '김정숙  드루킹 문다혜 손혜원한테 발목 잡힌다  서정욱의 법보다 주먹 ': array([0.09986674, 1.0956017 , 1.0264109 , ..., 0.0820803 , 0.21926132,
#         0.35889414], dtype=float32),
#  '중국은 힘으로 다뤄야한다  김정민박사 특별대담 ': array([0.05699351, 2.2894213 , 0.31212354, ..., 0.5376811 , 0.5688703 ,
#         0.19585851], dtype=float32),
#  '대한민국 기업은 다 죽었다  with 김정호 교수  특별대담 ': array([0.17170982, 2.073215  , 0.53901947, ..., 0.11063131, 0.1316648 ,
#         0.0229    ], dtype=float32),
#  ' 장기표의 직문직설   조국 은 신의 작품': array([0.2617532 , 2.366657  , 0.4312952 , ..., 0.030237  , 0.21318239,
#         0.4600644 ], dtype=float32),
#  '종교계가 왜 꼼짝 못하나 했더니  성창경의 미친언론 ': array([0.16104786, 1.7284425 , 0.72992444, ..., 0.0354983 , 0.19237077,
#         0.13820706], dtype=float32),
#  '주사파 정권때문에 큰일났다  with 박찬종 변호사  특별대담 ': array([0.18396138, 1.7797606 , 0.80137205, ..., 0.08340203, 0.47680146,
#         0.09101671], dtype=float32),
#  '제2의 박정희가 오고있다  미친언론 ': array([0.34585664, 1.7121619 , 0.357607  , ..., 0.04890375, 0.07214811,
#         0.15528226], dtype=float32),
#  ' 김정봉의 안보특급  미국  참수작전 준비 끝냈다': array([0.20835292, 2.3533955 , 0.9279685 , ..., 0.06954052, 0.1951416 ,
#         0.11110999], dtype=float32),
#  '김문수  황교안 전대출마하라  김문수 전지사 특별대담 ': array([0.13390282, 1.4018307 , 0.5861421 , ..., 0.01821375, 0.21523789,
#         0.09972706], dtype=float32),
#  '나를 구속하려면 문재인  조국 먼저  유튜버 통큰누나 특별대담 ': array([0.00172509, 1.3210133 , 1.0873996 , ..., 0.41493666, 0.41450626,
#         0.22827026], dtype=float32),
#  '문통  정치해서는 안될 사람  무능하기 짝이없다   장기표대표 특별대담 ': array([0.31457695, 1.3987728 , 0.13374394, ..., 0.3258083 , 0.37885222,
#         0.03388283], dtype=float32),
#  ' 장기표의 직문직설  문재인은 왜 조국을 버리지 못하는가 ': array([0.04411826, 1.6316315 , 0.31852528, ..., 0.01154643, 0.19720143,
#         0.13852505], dtype=float32),
#  '김무성 홍준표 유승민 김성태 권성동은 정계를 떠나라  조원진 대표 특별대담 ': array([0.0344761 , 0.6474554 , 0.7094953 , ..., 0.08182852, 0.2284291 ,
#         0.12270699], dtype=float32),
#  '문재인 결말  이렇게 될 것이다  공병호TV ': array([0.14470744, 2.0409691 , 0.45482075, ..., 0.05579427, 0.23872975,
#         0.15996064], dtype=float32),
#  '경제 위기의 시작  당신이 하지 않아야 할 7가지  공병호TV ': array([0.01187284, 1.3447783 , 0.04882328, ..., 0.09376911, 0.17787819,
#         0.06699127], dtype=float32),
#  '경제 위기  개인 대처법  공병호TV ': array([0.01978246, 1.3748323 , 0.03615153, ..., 0.06321027, 0.19728042,
#         0.1482456 ], dtype=float32),
#  '대통령 지지도 자체조사   10 도 안 나오는데요    공병호TV ': array([0.16302523, 1.385462  , 0.24237075, ..., 0.01472786, 0.22898158,
#         0.08460122], dtype=float32),
#  '미중 경제전쟁  이렇게 끝날 것이다  공병호TV ': array([0.00646126, 1.9576615 , 0.60251504, ..., 0.09585384, 0.20723802,
#         0.24881044], dtype=float32),
#  '경제 위기 핵심정리  공병호TV ': array([0.06226474, 2.2519226 , 0.01389124, ..., 0.01130692, 0.09477361,
#         0.11723296], dtype=float32),
#  '문재인   문재인 정부  친북 행보의 결말은    공병호TV ': array([0.14261909, 0.38799983, 0.19534074, ..., 0.12588681, 0.35067737,
#         0.23773083], dtype=float32),
#  '조국 사태   이렇게 될 것이다  공병호TV ': array([0.08481779, 1.3018725 , 0.        , ..., 0.00441318, 0.01069101,
#         0.22215188], dtype=float32),
#  '존재하지 않는   위대한 중국  공병호TV ': array([0.04960068, 1.8080556 , 0.12192792, ..., 0.0493831 , 0.02634398,
#         0.08820743], dtype=float32),
#  '총선 결과    2020년 4월 15일  공병호TV ': array([3.0338325e-02, 1.5636199e+00, 2.5654037e-04, ..., 2.5099877e-03,
#         1.8828998e-03, 1.3989992e-01], dtype=float32),
#  '윤석열  결국 해내다  공병호TV ': array([0.01222468, 1.6105382 , 0.09289395, ..., 0.04685356, 0.0733882 ,
#         0.14408556], dtype=float32),
#  '경제 위기의 시작   노년 에 해야 할 10가지  공병호TV ': array([0.04218116, 2.248945  , 0.08009885, ..., 0.11575656, 0.16964443,
#         0.04119819], dtype=float32),
#  '북한의 실상을   고발하다  공병호TV ': array([0.04205459, 1.2620953 , 0.06074449, ..., 0.09231225, 0.22275935,
#         0.16373527], dtype=float32),
#  '윤석열  대통령 되면  공병호TV ': array([0.09326255, 1.8025615 , 0.6367242 , ..., 0.10116039, 0.1608279 ,
#         0.303747  ], dtype=float32),
#  '현대자동차 과연 살아남을 수 있을까   공병호TV ': array([0.03489365, 1.9157721 , 0.2533499 , ..., 0.14494722, 0.15789852,
#         0.06975908], dtype=float32),
#  '이성윤  박살나다   서울중앙지검장에게 대든 검사들  공병호TV ': array([0.00849581, 1.4515493 , 0.48789838, ..., 0.25008363, 0.04432718,
#         0.04140177], dtype=float32),
#  '5년 후 한국  공병호TV ': array([0.0316307 , 0.7033361 , 0.09244476, ..., 0.18592544, 0.0130246 ,
#         0.11592597], dtype=float32),
#  '조국  앞날   똑똑이들의 인생길  공병호TV ': array([0.06662332, 2.4920642 , 0.51806307, ..., 0.06676654, 0.22665009,
#         0.05219557], dtype=float32),
#  '엘리트 탈북기자   북한 증언하다  공병호TV ': array([0.01273747, 2.5662172 , 0.12697026, ..., 0.14704683, 0.07215129,
#         0.32272807], dtype=float32),
#  ' 장용진의 학익진   중앙지검 3차장 임은정  검찰 뒤집힌다': array([0.5478608 , 1.1362668 , 1.5139266 , ..., 0.18466054, 0.44873425,
#         0.9614441 ], dtype=float32),
#  ' 특집  투표율 예측 성공  범진보 190석 그리고 박시영의 폰': array([0.10926553, 0.52025247, 0.01752997, ..., 0.02174448, 0.01647889,
#         0.06071403], dtype=float32),
#  ' 히히히스토리  퇴계 선생과 박정희의 성생활 야사  그리고 자한당나귀   ': array([0.24374232, 1.3526728 , 0.9146149 , ..., 0.24420954, 0.1425992 ,
#         0.2515777 ], dtype=float32),
#  ' 히히히스토리  박정희는 왜 악마인가   그의 가려진 민낯': array([0.35595694, 1.7633815 , 1.0053638 , ..., 0.52244055, 0.21604754,
#         0.15910271], dtype=float32),
#  ' 박시영의눈  노련한 추미애  윤석열 사퇴  그리고 윤상현 저지와 천정배 교체': array([0.26395947, 1.1832403 , 0.66968286, ..., 0.03814606, 0.4861431 ,
#         0.11267534], dtype=float32),
#  '관훈라이트  30 1  장자연  덮은 건 좃선 아닌 이 사람   feat  주진우 ': array([0.02929579, 0.7949107 , 0.8352341 , ..., 0.17347756, 0.39720026,
#         0.18293904], dtype=float32),
#  ' 박시영의눈  당선자 쫑파티  대장정 마감 그리고 박시영의 폰': array([0.5468406 , 0.68721384, 0.37413278, ..., 0.41633287, 0.26008874,
#         0.01823206], dtype=float32),
#  ' 용터뷰   진짜 죽을 수 있었구나  이재명 경기도지사': array([0.0776325 , 1.4170069 , 0.20527995, ..., 0.00479519, 0.0726501 ,
#         0.02579481], dtype=float32),
#  ' 관훈라이트   115 2 정통한 검찰 소식통  윤석열  잘못 발들인 듯 ': array([0.24089871, 0.6647626 , 1.0696832 , ..., 0.43708587, 0.41208902,
#         0.25401577], dtype=float32),
#  ' 관훈라이트   116 1 손석희와 JTBC는 왜 그럴까': array([0.41221392, 0.83934575, 1.2265924 , ..., 0.17269526, 1.1720223 ,
#         0.5769393 ], dtype=float32),
#  ' 장용진의 학익진  검찰은 왜 신천지 압수수색을 안할까 ': array([0.09151144, 1.4044049 , 0.2230903 , ..., 0.0907438 , 0.559552  ,
#         0.178287  ], dtype=float32),
#  ' 히히히스토리  조선시대의 변절자    윤석열과 진중권': array([0.27225852, 0.46848145, 1.5001785 , ..., 0.02711319, 0.6177371 ,
#         0.31624612], dtype=float32),
#  ' 히히히스토리   색욕의 신  성종 이승만 최태민': array([0.23084775, 1.192957  , 0.9391766 , ..., 0.0315395 , 0.20387529,
#         0.14227526], dtype=float32),
#  ' 장용진의 학익진   신천지 압수수색 못한다 던 윤석열    사흘 만의 태세 전환  왜 ': array([0.08252078, 1.2606831 , 0.3326272 , ..., 0.20918702, 0.45648968,
#         0.06397402], dtype=float32),
#  ' 정치부심   1 1 보다 신속하게 망하고 있는 한국당': array([0.00792987, 0.6589042 , 0.4641406 , ..., 0.        , 0.40870428,
#         0.06454778], dtype=float32),
#  ' 꼼찰청장   5 1 허둥지둥 윤석열  검언유착  스모킹 건  발견된 듯': array([0.25421908, 0.20754656, 0.20228666, ..., 0.10799257, 0.07427813,
#         0.4290976 ], dtype=float32),
#  ' 박시영의눈  안철수 복귀  추미애 vs 윤석열 그리고 김진태 아웃과 충청 세대교체': array([0.0972169 , 1.3384278 , 0.64116037, ..., 0.00282641, 0.22927858,
#         0.03434884], dtype=float32),
#  ' 히히히스토리  고종과 궁예가 섞인 황교안': array([0.04732933, 1.9935725 , 1.0938249 , ..., 0.32297632, 0.20407951,
#         0.32079855], dtype=float32),
#  ' 박시영의눈  선거법 완벽 시뮬레이션 그리고 대구가 뒤집힌다 ': array([0.16637453, 0.7118257 , 1.0680294 , ..., 0.00136615, 0.16535322,
#         0.04108878], dtype=float32),
#  ' 히히히스토리  미국은 왜 북한에 벌벌 떠나': array([0.32943052, 1.5930015 , 0.5779856 , ..., 0.17990007, 0.2613229 ,
#         0.25282788], dtype=float32),
#  ' 히히히스토리  김준혁 교수가 말하는  남산의 부장들  픽션과 논픽션': array([0.1515909 , 0.9081584 , 0.19718805, ..., 0.18841062, 0.41597813,
#         0.41627172], dtype=float32),
#  '5 18은 폭동이었다  당시 전남도청 근무 공무원 육성증언   5 18 북한군 개입 대국민 공청회    뉴스타운TV ': array([0.25118014, 0.9391924 , 0.182001  , ..., 0.14025408, 0.24761853,
#         0.25147587], dtype=float32),
#  ' 속보  김정은 사망설  북한이 심상치 않다   2019 05 31    뉴스타운TV ': array([0.17945385, 2.080003  , 0.72406054, ..., 0.06250816, 0.06994684,
#         0.12415151], dtype=float32),
#  ' 핵심체크  박원순 살해 진실 시신 발견 현장에서 밝혔다   손상윤 뉴스타운 회장  뉴스타운TV ': array([0.11873242, 1.9075036 , 0.36359522, ..., 0.07815751, 0.6567881 ,
#         0.01096784], dtype=float32),
#  '박원순 납치 살해 제보가 들어왔습니다   손상윤 뉴스타운 회장 2020 07 21  뉴스타운TV ': array([0.01852014, 2.2263832 , 0.3295588 , ..., 0.07994092, 0.20068689,
#         0.08248401], dtype=float32),
#  ' 긴급경계경보1호  국민 여러분 제발 깨어 나십시오   대한민국 운명의 날이 다가 왔다    뉴스타운TV ': array([0.04863523, 1.4629873 , 0.86189795, ..., 0.33237147, 0.4816668 ,
#         0.18148707], dtype=float32),
#  ' 현장취재  박원순 살해 제보 3탄   박원순 시신 발견 장소 북악산 현장을 가다   손상윤 뉴스타운TV 회장 2020 07 28  뉴스타운TV ': array([0.05889167, 1.7779133 , 0.608559  , ..., 0.11238291, 0.32399866,
#         0.02805184], dtype=float32),
#  '문재인 출생의 비밀 의혹 진실은 이것이다   흥남철수 때 왔다 는 것부터 거짓말   조우석 칼럼    뉴스타운TV ': array([0.23235862, 2.3054116 , 0.9927147 , ..., 0.17343046, 0.25234193,
#         0.08326285], dtype=float32),
#  '미국 북한정권교체 및 김정은 참수로 가고 있다   2019 한반도 정세분석 1    손상윤의 나사랑과 정의를 노래하리라 제116회 하이라이트    뉴스타운TV ': array([0.0049582 , 0.49292094, 0.23612964, ..., 0.05177937, 0.09195131,
#         0.13693132], dtype=float32),
#  ' 뉴스타운TV  소름돋는 연설  무상급식은 배급사회로  인구는 주는데 공무원이 무슨일 해  전희경': array([0.32195267, 0.29836395, 0.2375671 , ..., 0.02033069, 0.3152778 ,
#         0.06261806], dtype=float32),
#  ' 뉴스타운TV  북한 김정은과 최룡해는 이 방송을 보고나면 둘 중 하나는 반드시 죽는다  손상윤의 나 사랑과 정의를 노래하리라 제44회 ': array([0.59269786, 1.1878959 , 1.2844908 , ..., 0.14261413, 0.84550834,
#         0.33372107], dtype=float32),
#  ' 박원순 살해 제보 2탄   박원순 살해 전모를 밝힌다     손상윤 뉴스타운 회장 2020 07 24  뉴스타운TV ': array([0.04101504, 1.4891733 , 0.56806225, ..., 0.12335669, 0.1687952 ,
#         0.22766852], dtype=float32),
#  ' 뉴스타운TV   충격증언   광주 5 18 폭동  중  남한 고정간첩들 소행  부분에 대한 탈북자의 과학적 증언  손상윤의 나 사랑과 정의를 노래하리라 제71회 ': array([0.07745001, 1.1788121 , 0.7749632 , ..., 0.06578983, 0.5695494 ,
#         0.34877393], dtype=float32),
#  '이제는 더 이상 참을 수 없다  2019년 5월 18일 토 을 문재인 퇴진의 날로 선포한다   손상윤의 나 사랑과 정의를 노래하리라 제129회    뉴스타운TV ': array([3.9731089e-02, 9.0163618e-01, 3.8439861e-01, ..., 1.7717487e-01,
#         6.3244178e-04, 1.4124019e-01], dtype=float32),
#  '빨갱이 주교 강우일 화난 평신도가 작살낸다   조우석 칼럼 제77회    뉴스타운TV ': array([0.09478039, 1.253422  , 1.5995971 , ..., 0.40914345, 0.32759497,
#         0.07075066], dtype=float32),
#  ' 단독  광주 5 18 유공자 최초 양심선언 서의환 선생    손상윤의 나사랑과 정의를 노래하리라 제117회    뉴스타운TV ': array([0.12492052, 0.99047595, 0.3489641 , ..., 0.21442373, 0.11857372,
#         0.21414313], dtype=float32),
#  ' 강난희 씨  박원순 아내 큰일났다    남편 성추행 수사키로   조우석 칼럼 2020 07 16  뉴스타운TV ': array([0.0731019 , 0.5095845 , 2.1213076 , ..., 0.4758094 , 0.19359003,
#         0.28723028], dtype=float32),
#  '점점 커지는 타살 의혹 박원순 자살 아니다   조우석 칼럼 2020 07 20  뉴스타운TV ': array([0.06343766, 0.9411089 , 1.9880894 , ..., 0.3704112 , 0.11472286,
#         0.2091037 ], dtype=float32),
#  ' 뉴스타운TV  대통령 1달안에 청와대 복귀합니다  화제의 인물 헌법수호대 곽여호수아  검찰청 앞 태극기집회 연설': array([0.01667418, 1.2776453 , 0.3249653 , ..., 0.17969392, 0.39421463,
#         0.12806995], dtype=float32),
#  ' 박정희 대통령은 천재였다  이언주 바른미래당 국회의원   민족중흥회 송년 초청강연    뉴스타운TV ': array([0.12874499, 0.88159055, 1.2750688 , ..., 0.4907771 , 0.4339162 ,
#         0.03297854], dtype=float32),
#  '세월호 참사  단원고 생존 학생의 편지': array([0.33453116, 1.0283062 , 1.4772286 , ..., 0.45384255, 0.41605416,
#         0.17380492], dtype=float32),
#  '박사모 위협에 김제동 반응': array([0.10560493, 1.2557456 , 0.04473503, ..., 0.08919817, 0.05295929,
#         0.2972528 ], dtype=float32),
#  '박근혜 서문시장 방문  믿기지 않는 장면': array([0.1547305 , 0.6130169 , 0.690454  , ..., 0.08296477, 0.28761223,
#         0.5699185 ], dtype=float32),
#  '5 18 기념식  광주시민 감동시킨 대통령 경호원들': array([0.13224848, 1.0002431 , 0.8914845 , ..., 0.32972002, 0.3026332 ,
#         0.3398346 ], dtype=float32),
#  '어버이연합 기자회견 중 jtbc 기자들 분노폭발': array([0.14211087, 1.0612301 , 0.34776258, ..., 0.3318615 , 0.08852419,
#         0.0912812 ], dtype=float32),
#  '박근혜   하야하라   퇴진하라  듣고 난 후 표정': array([0.00113937, 0.46516317, 0.5584199 , ..., 0.04906023, 0.14348467,
#         0.05827747], dtype=float32),
#  '나경원 의원에게 친일파라 외친 대학생들': array([0.29548877, 1.1573752 , 0.2670015 , ..., 0.00269484, 0.21030714,
#         0.14916977], dtype=float32),
#  'MBC 아나운서들  눈물의 폭로 현장': array([0.71151483, 1.3457835 , 1.8845114 , ..., 0.30891132, 0.4535116 ,
#         0.15702835], dtype=float32),
#  '일본 일왕 생일파티 초토화 시킨 아줌마': array([0.11285648, 0.47631377, 0.37759772, ..., 0.06129007, 0.07436646,
#         0.5418874 ], dtype=float32),
#  '광화문 교복소녀  작은 행동 큰 울림': array([0.15054181, 1.6278925 , 2.0274317 , ..., 0.54527074, 0.46306327,
#         0.5501909 ], dtype=float32),
#  '김제동  손석희 앵커브리핑 팩트체크 하다': array([0.28433806, 1.9178587 , 0.44169655, ..., 0.05938054, 0.23198159,
#         0.06968802], dtype=float32),
#  ' 손석희 마지막  100분토론 보다 더 볼만한 대기실 기싸움': array([0.28487572, 0.9001427 , 1.4260588 , ..., 0.04717702, 0.24959986,
#         0.24810436], dtype=float32),
#  '광화문 촛불집회  뮤지컬 배우들 민중의 노래  전율 ': array([0.01194238, 0.9527331 , 0.34908345, ..., 0.20794639, 0.24696973,
#         0.3940941 ], dtype=float32),
#  '이명박 입장 발표 현장  기자들 분노 폭발': array([0.2138282 , 1.1377646 , 0.20941158, ..., 0.08658294, 0.24807563,
#         0.20654811], dtype=float32),
#  '김무성 대표에 욕설 토한 대학생들': array([0.07390088, 1.1669784 , 0.8405441 , ..., 0.15038498, 0.23557466,
#         0.1441485 ], dtype=float32),
#  '이명박 생일 잔치 초토화 시킨 시민들': array([0.00869924, 0.80780154, 0.17707011, ..., 0.18954194, 0.48915341,
#         0.4729085 ], dtype=float32),
#  '세월호 실종자 황지현  198일만에 친구들과 만남': array([0.00223934, 0.20585328, 1.3591827 , ..., 0.02815166, 0.28465447,
#         0.12551582], dtype=float32),
#  '이런 보수단체가 있을 줄이야': array([0.15203634, 2.6575756 , 0.34096414, ..., 0.48961574, 0.31299993,
#         0.28066066], dtype=float32),
#  '이명박 구속 지켜 본 주진우 기자 반응': array([0.02335463, 1.4253057 , 0.64221025, ..., 0.09007569, 0.13357411,
#         0.21300569], dtype=float32),
#  '외신이 감탄한 광화문 촛불 쓰나미': array([0.08115939, 0.60210603, 0.31486046, ..., 0.35616758, 0.00561711,
#         0.12505381], dtype=float32),
#  '노무현 대통령 6주기  노건호 돌직구에 김무성 표정': array([0.31242073, 0.81744885, 0.5350446 , ..., 0.34051934, 0.2833504 ,
#         0.09251435], dtype=float32),
#  '곽상도에 망신 당한 이낙연  문다혜 경호도 그만   팝콘각 ': array([0.07224191, 0.6663633 , 0.405578  , ..., 0.01750367, 0.42209083,
#         0.09014561], dtype=float32),
#  '100분': array([0.04259718, 1.0331938 , 0.54945755, ..., 0.10417361, 0.34676236,
#         0.3335161 ], dtype=float32),
#  '모른 척 ': array([7.8218809e-04, 1.5136013e+00, 8.2864690e-01, ..., 7.0799246e-02,
#         3.6547944e-01, 1.5527044e-01], dtype=float32),
#  '김경수 재판 망했다  열받은 항소심 여론재판 안한다 선언   팝콘각 ': array([3.9860763e-02, 1.2899721e+00, 9.0664572e-01, ..., 1.0885792e-04,
#         1.6315144e-01, 7.4839383e-02], dtype=float32),
#  '그 날  해경은 왜  검찰이 찾은 이것은  배승희 변호사 ': array([0.05482703, 0.7589455 , 0.6221139 , ..., 0.07891448, 0.1510811 ,
#         0.29383904], dtype=float32),
#  '외교천재 문재인이요  ㅋㅋㅋ 외교부장관마저도 쯧쯧  팝콘각 ': array([0.26170942, 1.8064823 , 0.42761615, ..., 0.09820168, 0.1756076 ,
#         0.43614247], dtype=float32),
#  '깜짝 놀란 여론조사  與 발칵 ': array([0.01505098, 0.48723486, 0.3626358 , ..., 0.00767296, 0.49340397,
#         0.08146498], dtype=float32),
#  '비엔나소세지': array([0.16259685, 2.4223814 , 0.6642111 , ..., 0.12167826, 0.4779691 ,
#         0.20530383], dtype=float32),
#  '제2의 윤석열 쏟아진다   검사들 어떻길래  따따부따 ': array([0.00777122, 0.788122  , 1.0439439 , ..., 0.07211728, 0.52327895,
#         0.04365727], dtype=float32),
#  '유쾌  상쾌  통쾌 ': array([0.01702413, 0.5261735 , 0.67002285, ..., 0.02206122, 0.377978  ,
#         0.10870307], dtype=float32),
#  '까불더니만  따따부따 2019  11  27 ': array([0.050936  , 0.81552273, 0.62054765, ..., 0.03861702, 0.29429385,
#         0.21234758], dtype=float32),
#  '대   반  전   따 따 ': array([0.0253198 , 0.9982355 , 1.5657883 , ..., 0.12765636, 0.34152007,
#         0.13278043], dtype=float32),
#  '어떤 결과가 나왔길래  ': array([0.06838523, 0.27449092, 0.10025561, ..., 0.16075361, 0.22322685,
#         0.28499123], dtype=float32),
#  '긴급  민영삼   김정숙 나낸다  말했나  이언주 토크콘서트에서 무슨일이    따따부따 ': array([0.2524492 , 1.2048317 , 0.55266917, ..., 0.19739741, 0.088692  ,
#         0.48889336], dtype=float32),
#  '나 떨고 있니 ': array([0.01641034, 1.1600927 , 0.52384907, ..., 0.0162515 , 0.2762254 ,
#         0.01211549], dtype=float32),
#  '새롭게 알게 된 사실은 ': array([0.03859452, 0.40827268, 0.8438011 , ..., 0.34253195, 0.20927727,
#         0.03238992], dtype=float32),
#  '블랙스카이  2019 12 02 ': array([0.01496868, 0.94085294, 0.1396751 , ..., 0.04115595, 0.50848246,
#         0.19885184], dtype=float32),
#  '특종  예고편  따따1부 ': array([0.0451302 , 1.0284642 , 1.5174947 , ..., 0.02436845, 0.27548087,
#         0.15398139], dtype=float32),
#  ' 긴급  조국 부부 거짓말 계속 들통  文 큰일났다   2019 09 13 따따부따 ': array([0.28253916, 1.6240821 , 0.80536526, ..., 0.1800909 , 0.39445037,
#         0.36332756], dtype=float32),
#  '자기 발에 걸렸다': array([0.11600796, 0.5011216 , 1.0162249 , ..., 0.05754378, 0.31640065,
#         0.13675408], dtype=float32),
#  '화들짝 놀란 與  설 특집 따따부따 ': array([0.03418788, 0.7778172 , 2.0708869 , ..., 0.13907954, 0.17527555,
#         0.07965875], dtype=float32),
#  '무슨 약점 있길래   따 따 ': array([0.06022722, 0.88694483, 1.5552586 , ..., 0.07723846, 0.4539209 ,
#         0.22311534], dtype=float32),
#  ' 속보  秋 또 실수 ': array([0.04468498, 1.3409315 , 1.0348204 , ..., 0.02937998, 0.16135247,
#         0.10638521], dtype=float32),
#  ' 유시민의 알릴레오 1회  문정인 대통령 통일외교안보 특별보좌관 1 ': array([0.29082268, 1.1244591 , 0.39792272, ..., 0.14192599, 0.0723984 ,
#         0.18914434], dtype=float32),
#  ' 유시민의 알릴레오 31회  유시민이 묻고 도올이 답하다   10 4 12주년 특별강좌 3강': array([0.22194368, 1.2126678 , 0.4489792 , ..., 0.53369373, 0.7500691 ,
#         0.04309178], dtype=float32),
#  ' 유시민의 알릴레오 22회 전반전   접속 홍카X레오 ': array([0.1128532 , 1.7401829 , 0.5319821 , ..., 0.28386807, 0.01945423,
#         0.1386571 ], dtype=float32),
#  ' 유시민의 알릴레오 59회  유시민의 마지막 정치비평': array([0.35939792, 1.3000398 , 1.4888713 , ..., 0.22582556, 0.55812377,
#         0.15102051], dtype=float32),
#  ' 유시민의 알릴레오 43회  2019년 총정리  김어준 Ver ': array([0.17786711, 1.5964947 , 0.644879  , ..., 0.05581099, 0.6852879 ,
#         0.11193059], dtype=float32),
#  '유시민 그리고 노무현 두 사람 이야기   ': array([0.29373363, 0.47979385, 1.0581287 , ..., 0.10436019, 0.42432243,
#         0.05803623], dtype=float32),
#  ' 고칠레오 1회  유시민  차기 대통령 자리를 노린다 ': array([0.1842584 , 1.1486382 , 0.44826344, ..., 0.15912864, 0.03600445,
#         0.06098997], dtype=float32),
#  ' 유시민의 알릴레오 10회  조국을 지켜라   공수처 설치 법안    조국 청와대 민정수석': array([0.36227667, 1.2012146 , 0.26222327, ..., 0.19420598, 0.07216828,
#         0.3515499 ], dtype=float32),
#  ' 유시민의 알릴레오 19회   사람  노무현    강원국 작가  김정호 더불어민주당 의원': array([0.3712218 , 1.207323  , 0.16327463, ..., 0.6082139 , 0.07641833,
#         0.24750736], dtype=float32),
#  ' 알릴레오 라이브 6회  어떻게 검찰이 그래요   19 10 29 ': array([0.12410441, 0.9802801 , 0.2642764 , ..., 0.14943019, 0.16098742,
#         0.0753483 ], dtype=float32),
#  ' 알릴레오 라이브 3회  윤석열 총장에게 띄우는 헌정방송  19 10 08 ': array([0.05334931, 0.8323168 , 0.27856168, ..., 0.20670788, 0.21030733,
#         0.0835099 ], dtype=float32),
#  ' 알릴레오 라이브 1회  유시민의  조국 사건  수첩 19 9 24 ': array([0.04016322, 1.107541  , 0.22121811, ..., 0.04005601, 0.624053  ,
#         0.15134099], dtype=float32),
#  ' 유시민의 알릴레오 2회  문정인 대통령 통일외교안보 특별보좌관': array([0.18739146, 1.2295679 , 1.0406237 , ..., 0.27254367, 0.06868346,
#         0.21566853], dtype=float32),
#  '2002년 대선 다큐  그날 ': array([0.07890828, 1.6009372 , 0.03025716, ..., 0.21976024, 0.18125643,
#         0.29117885], dtype=float32),
#  ' 알릴레오 라이브 3회 A S  검찰 언론 알라뷰': array([0.11269468, 1.0026714 , 0.42099786, ..., 0.16778515, 0.49150303,
#         0.06241544], dtype=float32),
#  ' 유시민의 알릴레오 22회 후반전   접속 홍카X레오 ': array([0.15357575, 1.6235828 , 0.484183  , ..., 0.2541784 , 0.03750085,
#         0.2055792 ], dtype=float32),
#  ' 알릴레오 라이브 29회  굿바이 알릴레오 시즌2  20 04 21 ': array([0.05076297, 0.8909729 , 0.09282981, ..., 0.11186603, 0.40339676,
#         0.01446896], dtype=float32),
#  ' 유시민의 알릴레오 28회    아베 가  말이야    Feat  일본의 무역제재    송기호 변호사  양기호 교수': array([0.06434195, 1.393539  , 0.519887  , ..., 0.14721617, 0.3761107 ,
#         0.05090915], dtype=float32),
#  ' 노무현 대통령 서거 11주기 특별영상   노무현의 시대가 올까요  ': array([0.2583263 , 0.86529064, 1.2973225 , ..., 0.13010716, 0.17652634,
#         0.0547456 ], dtype=float32),
#  ' 유시민의 알릴레오 8회  나쁜 언론 전성시대   변상욱 CBS 대기자': array([0.25504488, 1.3976619 , 0.51469654, ..., 0.12448892, 0.03448194,
#         0.1144954 ], dtype=float32),
#  ' 단독취재  박정희 상습 성폭행으로 희생된 천재 무용가이자  여배우 김삼화 ': array([0.06592971, 1.7785696 , 1.0383887 , ..., 0.1515108 , 0.1357715 ,
#         0.14059357], dtype=float32),
#  '박정희에게 희생된  여배우 김삼화  취재 400만 조회 돌파 기념 인터뷰': array([0.03004481, 1.8623611 , 0.62178695, ..., 0.01543405, 0.00988994,
#         0.06873961], dtype=float32),
#  ' 지만원  졸개 응징취재     김구 암살범  안두희가 애국자라니   ': array([0.08811948, 2.278986  , 0.5376526 , ..., 0.24213873, 0.70116735,
#         0.09189609], dtype=float32),
#  '서울의소리 박사모 응징취재  박근혜가 뭔데 태극기를 흔들어  ': array([0.06151587, 1.9787964 , 0.08916824, ..., 0.08737425, 0.28621745,
#         1.2241077 ], dtype=float32),
#  ' 돌발영상   미친새끼  조원진에게 되돌려 주다 ': array([0.21797143, 0.66079813, 0.9402423 , ..., 0.22402008, 0.15904716,
#         0.11063558], dtype=float32),
#  '홍준표 응징취재  이명박 BBK 내 아니면 아무도 못막아요   실토 ': array([0.06983467, 1.421044  , 0.33442613, ..., 0.10306499, 0.21172424,
#         0.24114445], dtype=float32),
#  '서울의소리 박사모 응징취재  일당받아 가세요 ': array([0.14587149, 1.2806164 , 0.2802762 , ..., 0.29806337, 0.43282458,
#         0.15846156], dtype=float32),
#  ' 나경원  왜 토착왜구라 불리는지 아는가  ': array([0.01622225, 1.2054703 , 0.82411134, ..., 0.11566772, 0.12420772,
#         0.06712029], dtype=float32),
#  '태극기 모독 부대 응징취재   헌법을 부정하는  역적놈 들아 ': array([0.54196346, 1.9612854 , 0.18606763, ..., 0.5876766 , 1.0926164 ,
#         0.21018404], dtype=float32),
#  ' 진실 보도   촛불집회에서 쫓겨나는 SBS  진실보도 요구당하는 JTBC ': array([0.01417126, 1.1557199 , 0.04079783, ..., 0.07795545, 0.16281249,
#         0.3749    ], dtype=float32),
#  ' 혼수  김성태   졸개  장제원 응징취재 갔더니   ': array([0.09214818, 1.0455513 , 0.94965804, ..., 0.1547613 , 0.7628472 ,
#         0.50910395], dtype=float32),
#  '서울의소리 김을동 응징취재   박근혜 밑에서 권력을 누리더니   왜   ': array([0.02065275, 0.16025825, 0.9515187 , ..., 0.0298763 , 0.25227556,
#         0.38196194], dtype=float32),
#  '이재명 지사    시작 3분15초 만에 15 대 0 으로 KO 압승   박살나는 국짐당 박성민 ': array([0.11927176, 1.3397704 , 1.8180007 , ..., 0.2636621 , 0.5070776 ,
#         0.28258118], dtype=float32),
#  '서울의소리 박사모 응징취재  변절자 김문수  응징취재 당하다 ': array([0.20460646, 2.0121162 , 0.3885213 , ..., 0.48940292, 0.471498  ,
#         0.47430304], dtype=float32),
#  '류석춘 응징취재    너를 일본간첩 현행범으로 체포 하겠어  ': array([0.05946877, 2.0780172 , 0.34987146, ..., 0.18358028, 0.1478602 ,
#         0.25012735], dtype=float32),
#  ' 긴급  이만희 체포   이재명 지사 출동': array([0.02415225, 1.0951045 , 0.2378663 , ..., 0.00466498, 0.11542963,
#         0.13025527], dtype=float32),
#  '신연희 응징 취재    인성  참 많이 삐뚤어 졌구나 ': array([0.0238823 , 1.8849355 , 0.2809933 , ..., 0.20278773, 0.5136564 ,
#         0.29619852], dtype=float32),
#  '이명박 졸개    홍준표  이동관  장제원 응징취재   ': array([0.1051823 , 3.0894575 , 0.59183156, ..., 0.23957591, 0.432915  ,
#         0.17109844], dtype=float32),
#  '세월호 유족  침몰 8시간 후 찍은 동영상 공개_서울의소리': array([0.5168843 , 0.3182345 , 0.2749366 , ..., 0.01038903, 0.2948727 ,
#         0.16817264], dtype=float32),
#  ' 서울의소리  빤스목사 전광훈 응징취재    김용민  박원순  주진우  도올이 北통전부 간첩 ': array([2.0910364e-01, 1.4835733e+00, 3.3064866e-01, ..., 1.0528658e-03,
#         2.6658344e-01, 3.4305361e-01], dtype=float32),
#  '참 부끄럽다  김정숙': array([0.11394078, 0.5702202 , 0.699029  , ..., 0.05342676, 0.05177264,
#         0.01582156], dtype=float32),
#  '문재인 추종자 김갑수 결국  ': array([0.32682735, 1.5533519 , 0.33496767, ..., 0.45692873, 0.24455848,
#         0.03894793], dtype=float32),
#  '우병우 충격 근황': array([0.11608533, 1.4618354 , 1.1121119 , ..., 0.16349594, 0.07953459,
#         0.10797331], dtype=float32),
#  ' 깨시민  김제동  어디로갔나  가짜 깨시민들에게': array([0.13654578, 1.2239169 , 0.4001501 , ..., 0.09360346, 0.04633869,
#         0.21786183], dtype=float32),
#  '문재인 존경한다던 고민정의 최후': array([0.04359422, 0.60477126, 1.8032832 , ..., 0.18834458, 0.18170917,
#         0.01019588], dtype=float32),
#  '가왕 조용필 충격 실체': array([0.06259928, 0.9572123 , 0.9589783 , ..., 0.17423269, 0.27887496,
#         0.07087196], dtype=float32),
#  '서장훈 큰일났다  ': array([0.2810813 , 0.96625006, 1.3407015 , ..., 0.21416494, 0.11522339,
#         0.15305835], dtype=float32),
#  '문재인 존경하던 고민정 결국  ': array([0.2137487 , 0.91355515, 1.279651  , ..., 0.30601594, 0.10852982,
#         0.15531895], dtype=float32),
#  '정유라 충격 근황': array([0.01579578, 0.47695044, 0.9592148 , ..., 0.16164918, 0.20338808,
#         0.13234977], dtype=float32),
#  '돈을 그렇게 쓸어담더니  ': array([0.06363672, 0.9035358 , 1.0872589 , ..., 0.15226874, 0.13373335,
#         0.17230645], dtype=float32),
#  '충격 폭로  민식이 부모의 실체는 ': array([0.09289251, 1.1964046 , 0.38057464, ..., 0.11048098, 0.01405002,
#         0.02015158], dtype=float32),
#  '성제준이 망언을 했다는 손석희 씨께 ': array([0.38867086, 0.68366706, 0.7611336 , ..., 0.10491613, 0.12392638,
#         0.22647843], dtype=float32),
#  '서장훈씨 큰일났네요  ': array([0.2057487 , 1.2639192 , 1.0289336 , ..., 0.32103586, 0.08683227,
#         0.11586028], dtype=float32),
#  '손사장 녹취 파일 충격 ': array([0.40158534, 0.6635242 , 0.72728246, ..., 0.11243238, 0.13227111,
#         0.24796316], dtype=float32),
#  ' 민식이 부모의 거짓말로 인해   ': array([0.10511839, 2.4502468 , 0.1670217 , ..., 0.4025819 , 0.24290664,
#         0.0996787 ], dtype=float32),
#  '설민석 강사님의 역사왜곡을 알아보자': array([0.04915595, 1.4508978 , 0.42116398, ..., 0.14165553, 0.2777312 ,
#         0.06899501], dtype=float32),
#  '손석희 JTBC 충격 근황  난리났다 ': array([0.10749324, 1.0787991 , 1.2316345 , ..., 0.2760585 , 0.08715325,
#         0.1067093 ], dtype=float32),
#  '뭐 이런 여자가 다 있나 ': array([0.11065204, 0.64813226, 0.6925311 , ..., 0.04423584, 0.04992403,
#         0.02012667], dtype=float32),
#  '김세의 기자님께 ': array([0.22392425, 0.9398053 , 0.35728338, ..., 0.3295133 , 0.16716714,
#         0.35057715], dtype=float32),
#  '정은경의 충격 실체': array([0.05245201, 1.2067401 , 0.23637296, ..., 0.29823026, 0.1301013 ,
#         0.04541071], dtype=float32),
#  '어제 실검 1위 달리던 신보라 과거  이재명 시장 한테 덤비다 혼나는 참교육 영상 ': array([0.26184583, 0.56218976, 1.6690024 , ..., 0.2827599 , 0.28635097,
#         0.05807297], dtype=float32),
#  '김성태의원 단식농성 생방송 중 돌발상황 발생  제발 정신 좀 차리세요 아주머니 ': array([0.07273562, 2.9036093 , 0.07805624, ..., 0.3764785 , 0.41177097,
#         0.14072381], dtype=float32),
#  '김민석 카리스마 폭발  산케이 구로다 도발하다 본전도 못차렸다 ': array([0.10218101, 0.65459955, 1.5973084 , ..., 0.01007488, 0.20274863,
#         0.03542138], dtype=float32),
#  '표창원 뜨자  조용해진 자유한국당 의원들  빨갱이 원조 박정희를 밝히다': array([0.13757886, 0.7785026 , 0.8627261 , ..., 0.19885957, 0.35309014,
#         0.15506898], dtype=float32),
#  '참던 진선미 결국 폭발  어설프게 입법문제 제기한 전희경 참교육 ': array([0.08674052, 0.37610266, 1.2438787 , ..., 0.05793063, 0.4117078 ,
#         0.32874385], dtype=float32),
#  '도올   박근혜는 최순실의 아바타  무당춤 춘 것   폭탄발언 ': array([0.12822773, 1.8025715 , 0.782015  , ..., 0.09766027, 0.43357253,
#         0.35517567], dtype=float32),
#  '어떨결에 폭로한 장시호 김종 차관보다 우리 이모가 더 높다 이규혁 선수에게 말한걸 증언': array([0.2734329 , 0.6907953 , 0.44742838, ..., 0.10183821, 0.129037  ,
#         0.0174193 ], dtype=float32),
#  '영상3 제7차 서초대첩 검찰개혁 조국수호 200만집결   LIVE  ': array([0.04191027, 1.2585933 , 0.69371796, ..., 0.6283495 , 0.9939529 ,
#         0.23437136], dtype=float32),
#  '안민석  우병우 짜증에  뭐하러 나왔어요  집에가세요  다시 현상금 걸테니까  ': array([0.09061149, 0.5189872 , 1.0774621 , ..., 0.0742515 , 0.05405163,
#         0.10372022], dtype=float32),
#  '본전도 못 차린 日기자ㅡ거침없는 최재성 팩트폭행': array([1.5703458e-03, 1.6112916e+00, 5.4075372e-01, ..., 4.9604401e-03,
#         2.1286231e-01, 2.1586990e-01], dtype=float32),
#  '풀영상 제8차  검찰개혁 사법적폐청산  촛불문화제 서초역 사거리 LIVE ': array([0.0890824 , 1.1579635 , 0.03672   , ..., 0.19573212, 0.04111503,
#         0.0294537 ], dtype=float32),
#  ' 말이 꼬이는 조여옥 그의 친구 이슬비 자세 나쁘다고 혼나는 우병우 ': array([0.20644702, 1.0316621 , 0.6948512 , ..., 0.20599842, 0.22446786,
#         0.14147228], dtype=float32),
#  '2018년 봉하음악회를 발칵 뒤집어 놓은 김경수 지사의 깜짝 노래실력': array([0.34678546, 1.0675744 , 1.6210773 , ..., 0.4690097 , 0.2373555 ,
#         0.3798561 ], dtype=float32),
#  '악마기자 주진우  최순실 30년 친구들 최순실 임신한 모습을 본 적이 없었다 ': array([0.44488454, 0.36650446, 1.7004796 , ..., 0.04164629, 0.19592477,
#         0.10217787], dtype=float32),
#  '고영태 폭탄발언  최순실  세월호 노란색만 봐도 좋게 생각하지 않았다  ': array([0.11129484, 0.43123758, 0.60923463, ..., 0.00299736, 0.41413015,
#         0.28207374], dtype=float32),
#  '이재정 의원과 임은정 검사가 만났을때    검찰이 없어져도 할 말 없다  국정감사 중': array([0.04817931, 0.51646745, 0.47526243, ..., 0.20317651, 0.45867467,
#         0.02058028], dtype=float32),
#  '박근혜 하야집회    퇴근길 못가게 막고   시민들 버스밑으로 기어나가는 어이없는 현장': array([9.2553213e-02, 7.1794158e-01, 2.4565339e-01, ..., 7.9690763e-05,
#         7.4322349e-01, 1.4533858e-01], dtype=float32),
#  '박근령 육여사  생전에  최태민 조심하라  박근령 증언 신동욱 폭로': array([0.00660723, 0.53052044, 1.5849532 , ..., 0.07693721, 0.12105564,
#         0.17524432], dtype=float32),
#  '김민석 카리스마  아무리 수구세력이 일어나도 꺼지지 않는 촛불이 있다 ': array([0.16211568, 1.4311332 , 0.46214807, ..., 0.68920135, 0.06081931,
#         0.07254256], dtype=float32),
#  ' 수준있는 질문 수준있는 답변  자유한국당도 경청하게 만든 박주민 의원': array([0.17679034, 0.8625445 , 0.37181473, ..., 0.02692229, 0.24681354,
#         0.38271642], dtype=float32),
#  '유시민   이땅에 기레기들에게 참교육  작심발언': array([0.2317405 , 1.4350246 , 1.0606757 , ..., 0.14467846, 0.55869424,
#         0.04101708], dtype=float32),
#  ' 문재인 대통령은 누구보다 윤석렬과 검찰을 잘 파악하고 있다 ': array([0.06538373, 1.8607849 , 0.7174545 , ..., 0.08526219, 0.07051796,
#         0.07519751], dtype=float32),
#  '더민주 김민기 의원 해외 송금 환전내역 추궁하자  쩔쩔 매는 조윤선 후보자 ': array([0.14820507, 0.82555664, 0.737499  , ..., 0.25875238, 0.274633  ,
#         0.1379506 ], dtype=float32),
#  '이재명 지사 김은혜 참교육 국정감사란 팩트를 확인하고 대안을 만드는 것 ': array([0.14099246, 0.56241506, 2.0012445 , ..., 0.40133783, 0.93893963,
#         0.6787117 ], dtype=float32),
#  '이재용 충격 선언  공장은 베트남 본사는 미국으로   신혜식의 진짜뉴스    신의한수': array([0.05978529, 1.0571254 , 0.90155333, ..., 0.01652576, 0.12373149,
#         0.2440864 ], dtype=float32),
#  ' 현장취재  광화문 100만 모였다  광화문으로 계속 집결 중    신의한수 20 08 15': array([0.32810923, 1.7626725 , 0.18882318, ..., 0.30964047, 0.717007  ,
#         0.06248735], dtype=float32),
#  '김태우  문재인 딸 불륜 폭로   순찰팀 뉴스    신의한수': array([0.08370987, 1.7564275 , 0.18223134, ..., 0.20041169, 0.28192133,
#         0.0804803 ], dtype=float32),
#  '김정은 6월 사망설  박민찬 원장    신의한수': array([0.12342142, 2.8300364 , 0.16514093, ..., 0.01231082, 0.06893269,
#         0.1691213 ], dtype=float32),
#  '특종  박원순 CCTV 또 터졌다  영상이 충격   홍철기 사회부장    신의한수': array([0.18780577, 1.4292759 , 0.79414946, ..., 0.1919611 , 0.09556025,
#         0.69627154], dtype=float32),
#  ' 현장취재  광화문 천만 모였다    애국 시민들 청와대로 진격      신의한수 19 10 09': array([0.03587716, 1.108479  , 0.3054619 , ..., 0.22570902, 0.11419009,
#         0.08887307], dtype=float32),
#  ' 현장취재  광화문 진짜 500만 모였다    문재인 방빼      신의한수 19 10 03': array([0.17770676, 0.71343255, 0.07623915, ..., 0.3444814 , 0.03835675,
#         0.11405239], dtype=float32),
#  '신의한수의 새로운 시작    2백만 프로젝트   ': array([0.01570813, 0.22834891, 0.06720318, ..., 0.17833589, 0.01981001,
#         0.13562462], dtype=float32),
#  ' 다반뉴스  고X정 불륜  민주당 개망신 영상 떴다    신의한수 20 08 05': array([0.06361113, 1.2713419 , 0.7853955 , ..., 0.33344474, 0.12587196,
#         0.0328576 ], dtype=float32),
#  '천주교도 문재인 정권 타도 나선다  정치 사제 퇴출운동 시작   이계성 대수천 대표    신의한수 19 02 06': array([0.09913573, 2.0654166 , 0.20336685, ..., 0.00756693, 0.12392336,
#         0.28108728], dtype=float32),
#  ' 다반뉴스  속보  박원순 유서 남기고 실종  미투 터졌다    신의한수 20 07 09': array([0.03297629, 2.6391747 , 1.1615248 , ..., 0.23411733, 0.40517998,
#         0.44038433], dtype=float32),
#  '이재용  평양냉면 먹고 변했다  대한민국 떠나나   신혜식의 진짜뉴스    신의한수': array([0.24214807, 1.407367  , 1.7023484 , ..., 0.17988105, 0.20351088,
#         0.12824199], dtype=float32),
#  ' 일일뉴스  청와대 결국 조국 내치기로 결정    조국 배신에 부글부글      신의한수 19 09 25': array([0.0399305 , 0.4693767 , 0.36119395, ..., 0.0133514 , 0.06494734,
#         0.14070958], dtype=float32),
#  '문재인 딸 문제 밝혀지면 정권 끝나   전옥현 전 국정원 1차장    신의한수': array([0.02265372, 0.1837397 , 1.062405  , ..., 0.03340886, 0.10073774,
#         0.38947737], dtype=float32),
#  '현대자동차 정몽구 회장이 사라졌다  무슨 일이 생겼나   김정호 교수    신의한수': array([0.13883369, 1.5920547 , 0.62506944, ..., 0.01615348, 0.40142792,
#         0.39430705], dtype=float32),
#  '윤석열  조국 구속으로 결론     홍철기 사회부장    신의한수': array([0.10657318, 1.3106965 , 0.51102084, ..., 0.09345146, 0.25387138,
#         0.27651325], dtype=float32),
#  '이재용 압수수색  자택 때려 부숴     신혜식의 진짜뉴스    신의한수': array([0.02751929, 2.130249  , 0.37848967, ..., 0.2691608 , 0.15929882,
#         0.10875021], dtype=float32),
#  '신의한수 생중계 9월 29일   노무현 자살의 미스테리 집중분석   5시 뉴스 ': array([0.75031334, 2.501513  , 0.48522148, ..., 0.10009537, 0.3108651 ,
#         0.07087182], dtype=float32),
#  ' 현장중계  한국당 집회 어마어마한 규모로 모였다    독재자 문재인 끌어내자      신의한수 19 04 27': array([0.05242926, 0.37338057, 0.04471113, ..., 0.13601255, 0.03137917,
#         0.0810086 ], dtype=float32),
#  '정경심 자백 터졌다    모든 일은 남편 조국이 했다     홍철기 사회부장    신의한수': array([0.28597236, 0.76054484, 0.33287224, ..., 0.03421037, 0.20824903,
#         0.3215826 ], dtype=float32),
#  '신의한수 생중계 10월 16일   박근혜 대통령을 잘못 건드린 문재인 ': array([0.1996634 , 1.3525798 , 0.46937525, ..., 0.07073295, 0.47511193,
#         0.50413084], dtype=float32),
#  '문재인 사위 대형사고   전옥현 전 국정원 1차장    신의한수': array([0.3337668 , 2.4252765 , 0.6886338 , ..., 0.17141922, 0.22813235,
#         0.2034953 ], dtype=float32),
#  '한국공군 F 35A 13대가 뜨면 벌어지는 일 ': array([0.12066984, 1.3828912 , 0.34974024, ..., 0.26665294, 0.01676542,
#         0.08942334], dtype=float32),
#  '전면전  미군은 北 하늘을 몇 시간만에 완전 제압하나   전작권특집 ': array([0.37312275, 0.5674813 , 1.5279291 , ..., 0.18800735, 0.3176071 ,
#         0.03274889], dtype=float32),
#  '북폭  어떤 무기로 얼마나 걸릴까  北 미사일제거 완전분석 ': array([0.63773984, 1.2317358 , 1.2923194 , ..., 0.11819527, 0.40626946,
#         0.06158682], dtype=float32),
#  '미 항모 격침 위협하는 중국  살기 싫은가 ': array([0.3231616 , 0.7328893 , 0.41506597, ..., 0.19940428, 0.3732171 ,
#         0.05475186], dtype=float32),
#  '美  역대급 전쟁물자 한반도 집결 중  전면전 결심했나 ': array([0.30372167, 0.5057552 , 0.6316695 , ..., 0.05954517, 0.1261456 ,
#         0.23840185], dtype=float32),
#  ' 완전분석  화웨이의 충격적인 실체  이 정도였을 줄이야 ': array([0.11104533, 0.7190733 , 0.6819564 , ..., 0.01263222, 0.17719312,
#         0.23664321], dtype=float32),
#  '北  리병철 쿠데타 성공 정황  金 남매  권력 상실한듯 ': array([0.04301084, 1.9376953 , 0.15389483, ..., 0.20331527, 0.4753737 ,
#         0.06756507], dtype=float32),
#  '日에 30분만에 전멸되는 1함대  독도 입으로만 지키나 ': array([0.18499534, 0.6644988 , 0.4068721 , ..., 0.20935759, 0.17265555,
#         0.06445668], dtype=float32),
#  '美  로널드레이건  vs 中  랴오닝  항공모함  누가 셀까 ': array([0.49772763, 0.7729322 , 0.14006416, ..., 0.04815258, 0.18714194,
#         0.25015503], dtype=float32),
#  ' 특집  南 北 공군 전투기 전력비교 ': array([0.29518375, 1.0002085 , 0.428654  , ..., 0.16626611, 0.14833808,
#         0.12589148], dtype=float32),
#  ' 속보  15억원짜리 항공모함 매물 등장  당장 구입해야 ': array([0.11150388, 0.6496529 , 0.06911048, ..., 0.12031164, 0.01210918,
#         0.04171016], dtype=float32),
#  ' 특종  남한 유령선 NLL 월북  북한에서 사라지다 ': array([0.2323291 , 2.0345485 , 0.05099681, ..., 0.05123584, 0.726089  ,
#         0.04348097], dtype=float32),
#  '북한전차 한번에 16대 격파  육군  AH 64E 아파치  공격헬기': array([0.01788801, 1.0302802 , 0.10150271, ..., 0.16109431, 0.04861317,
#         0.38853317], dtype=float32),
#  ' 팩트체크  남중국해 핵폭발  中  美 핵잠수함 격침 ': array([0.17563288, 0.4597618 , 0.03080625, ..., 0.0764458 , 0.16326222,
#         0.04600558], dtype=float32),
#  '韓 K 2 흑표전차 vs 中 99식 전차 전력비교 ': array([0.26855582, 0.6768854 , 0.29546088, ..., 0.05520145, 0.8188362 ,
#         0.23938525], dtype=float32),
#  '김정은 사망 임박  호흡기 떼자 ': array([0.39451727, 2.3550637 , 0.896785  , ..., 0.09898192, 0.15482457,
#         0.2745523 ], dtype=float32),
#  'CIA  충격적인 극비 암살무기 공개  金  칼 맞을지도 ': array([0.2869022 , 0.48254943, 0.14248429, ..., 0.1311558 , 0.07324667,
#         0.1443929 ], dtype=float32),
#  '美  중ㆍ러는 상대가 안되는 극초음속 무기 성공  ': array([0.22480486, 0.21613413, 0.05568417, ..., 0.24532157, 0.3820693 ,
#         0.02233882], dtype=float32),
#  ' 완전분석  한국형 항공모함   KCVX ': array([0.18772219, 0.55724317, 0.02326899, ..., 0.00079813, 0.72244865,
#         0.18001667], dtype=float32),
#  ' 분석  北  서울불바다 만들 능력 되나 ': array([0.34350318, 1.7344899 , 0.17184396, ..., 0.16129391, 0.1437506 ,
#         0.00315182], dtype=float32),
#  '해군 3000톤급 잠수함부대 출범  21세기 거북선되나 ': array([0.341895  , 0.4764357 , 0.11797168, ..., 0.36114672, 0.8949697 ,
#         0.42969245], dtype=float32),
#  '인도 파키스탄 공중전 분석  韓 FA 50 어부지리 이득볼 판 ': array([0.20353697, 1.5297354 , 0.29612705, ..., 0.32740274, 0.14230157,
#         0.37676147], dtype=float32),
#  '美ㆍ中  北 처리 합의  金 체포작전 부대가 움직인다 ': array([0.04867881, 0.99773306, 0.5072713 , ..., 0.25813824, 0.3641374 ,
#         0.43342924], dtype=float32),
#  '北 항공기 15사단 지나 강원도 관통 정황  軍 은폐ㆍ조작 시도 ': array([0.30749857, 1.4964457 , 1.1071855 , ..., 0.4140143 , 0.18724926,
#         0.24671115], dtype=float32),
#  '일본이 다시 수출한다고 해도 안받을 현재 상황   세계 1위 반도체국가 대한민국의 반격이 시작되었다 ': array([0.15649594, 1.9301609 , 0.03107343, ..., 0.04754928, 0.29847282,
#         0.18414332], dtype=float32),
#  '최근 콜롬비아 해군이 한국 태극마크를 사용하고 있는 이유   한국이 준 무기 썼다가 중남미 전체에 화력 자랑중 ': array([0.02747875, 1.1088012 , 0.25171405, ..., 0.12546866, 0.560705  ,
#         0.07449292], dtype=float32),
#  '현재 한국인 사라진 일본에 중국관광객이 오자 충격받은 상황   가는곳마다 초토화  이정도일줄 몰랐다며 비명 ': array([0.09369048, 1.7286899 , 0.00200712, ..., 0.05406627, 0.26163194,
#         0.05066028], dtype=float32),
#  '한국은 막고 일본은 안막았던 베트남 근황   현재 전세계가 한국제품 달라는데  일본의 예상치 못한 일까지 겪게된 베트남 현상황 ': array([0.18476276, 1.1623963 , 0.62517315, ..., 0.12222242, 0.71916986,
#         0.34589103], dtype=float32),
#  '한국 불매운동에 난리난 일본기업들이 아무말도 못하는 이유   충격적인 일본의 언론통제 현실 ': array([0.18881786, 0.55105877, 0.08574769, ..., 0.05087674, 0.7134285 ,
#         0.14227512], dtype=float32),
#  '한국의 일제 불매운동을 본 세계여론의 뜨거운 반응   사지도 않는데  팔지도 않는다 ': array([0.3401351 , 0.84197825, 0.07589439, ..., 0.00178855, 0.36930805,
#         0.04560388], dtype=float32),
#  '한국이 도쿄올림픽 보이콧하면 일본이 난리나는 이유   충격적인 도쿄의 수치공개  일파만파 ': array([0.0609992 , 1.8171672 , 0.08625966, ..., 0.08802798, 0.38107628,
#         0.276431  ], dtype=float32),
#  '프랑스에서 일본선수 때문에 중국 크게 화가 나자 손흥민 소환된 이유   한 아이의 모습을 본 손흥민이 영국을 감동시킨 놀라운 이유 ': array([0.22565134, 0.82296675, 0.20646322, ..., 0.1503111 , 0.82200855,
#         0.19439925], dtype=float32),
#  '결국 아베까지 나서게 만든 한국 불매운동의 엄청난 타격   일본 현지인들의 불만이 목까지 차올랐다 ': array([0.14663097, 1.0509382 , 0.10345729, ..., 0.06060676, 0.2760024 ,
#         0.20491427], dtype=float32),
#  '유엔 사무총장의 한국관련 발언에 이탈리아인의 심금을 울려버린 이유  기술력의 나라 한국이 각성하면 벌어지는 놀라운일들': array([0.09184512, 0.7641769 , 0.059256  , ..., 0.11130314, 0.28704017,
#         0.10012779], dtype=float32),
#  '미국이 방위비 압박하자 한국이 최신예 전력들을 발표해버린 현상황   유럽최강의 전력까지 탑재  압도적인 국방력으로 대답한 한국 ': array([0.12994759, 1.0731171 , 0.14098397, ..., 0.00368499, 0.17142822,
#         0.09931691], dtype=float32),
#  '현재 손흥민 경기중 나온 장면을 해외에서 크게 놀라워 하는 이유  흥분한 영국축구팬들   웃돈 주고서라도 손흥민 데려와라 ': array([0.1718528 , 0.6215386 , 0.4381824 , ..., 0.05802799, 0.4221677 ,
#         0.22684714], dtype=float32),
#  '한국전 예상 시나리오에 일본이 첫번째 타깃이라는 놀라운 이유  미국언론   한국은 전세계 유일한 두려움이 없는 국가 ': array([0.05393483, 0.92385894, 0.00324828, ..., 0.11811651, 0.2016382 ,
#         0.0255789 ], dtype=float32),
#  '한국 불매운동 단3주만에 일본제품 매출 절반으로 급락   아마 전세계에서 대한민국에서만 가능한 일 ': array([0.23494299, 1.3532716 , 0.2048407 , ..., 0.06715729, 0.47204816,
#         0.07340275], dtype=float32),
#  '일본이 한국의 동해영토훈련에 크게 당황하며 난리치는 이유    일본을 단숨에 제압할 최강무기 봉인해제 완료 ': array([0.1327686 , 1.5162337 , 0.1788084 , ..., 0.10601921, 0.4988098 ,
#         0.15311895], dtype=float32),
#  '일본 경제보복에 파산위기 처한 일본기업들의 충격적인 현상황   믿었던 미국  대만에서 거절  이제는 삼성  SK 없으면 안돼 ': array([0.08104548, 1.8961468 , 0.39657468, ..., 0.16677761, 0.6738277 ,
#         0.23065773], dtype=float32),
#  '한국의 일제 불매운동 1달만에 이제서야 사태파악된 일본의 반응': array([0.13154538, 1.4161979 , 0.1488619 , ..., 0.07885319, 0.42911106,
#         0.18309587], dtype=float32),
#  '지금 전세계에서 한국을  이상한 선진국 이라고 말하는 이유  국민들을 포기하지 않는 나라   도대체 한국인의 끝은 어디인가 ': array([0.38090706, 0.80973923, 0.17211528, ..., 0.09417552, 0.3876834 ,
#         0.29997066], dtype=float32),
#  '유럽전역이 한국식 모델 따라하는데 일본 따라하다가 난리난 국가 현상황  결국 이태리 도시 엄청난 선언   정부말고 한국정책 따르겠다 ': array([0.1739395 , 2.244109  , 0.09144302, ..., 0.17618127, 0.7226983 ,
#         0.23485802], dtype=float32),
#  '영국언론의 보고서에서 밝힌 한국인은 정말 놀랍다는 이유   일본인들과 정반대 유전자 가진 한국인들 ': array([0.30725914, 1.3142295 , 0.1271595 , ..., 0.186325  , 0.3372851 ,
#         0.13170807], dtype=float32),
#  '현재 스페인 방송을 뒤집어 놓은 한국인 아나운서의 놀라운 발언   이제는 미국 중고등학교 수업시간에도 한국방식을 배워야 한다는 현상황 ': array([0.08958231, 1.6706438 , 0.06861718, ..., 0.06958177, 0.14505991,
#         0.04943994], dtype=float32),
#  '유니클로 공짜 내복 대란에 예상치 못한 대반전이 일어난 상황   결국 일본 최후의 불씨마저 꺼뜨리는 한국 ': array([0.1975814 , 1.6073203 , 0.13644902, ..., 0.07750464, 1.0138841 ,
# ...
#         0.12920906], dtype=float32),
#  ' 어서와리플레이  한국의 치안에 놀란 남아공 친구들  밤산책은_처음이라 행복 l  어서와한국은처음이지 l EP 86': array([0.27758098, 1.0720001 , 0.2333051 , ..., 0.00990947, 0.07223226,
#         0.19825098], dtype=float32),
#  ' SHOWCHAMPION  방탄소년단   INTRO   쩔어  BTS   INTRO   DOPE  l EP 151': array([0.1746557 , 1.4632089 , 0.16610636, ..., 0.09719206, 0.26261073,
#         0.18814375], dtype=float32),
#  ' 월요병예방  아이유 IU  가 부르는  가끔 미치도록 네가 안고 싶어질 때가 있어    l  피크닉라이브소풍': array([1.4352651, 2.1621895, 2.9315448, ..., 1.0721879, 0.3216829,
#         0.6325766], dtype=float32),
#  '말이 필요 없는 하은이의 K팝 메들리 댄스   엑소 X ITZY X 마마무  l  비디오스타 l EP 195': array([0.22890909, 0.82378256, 0.5890318 , ..., 0.21650164, 0.27694637,
#         0.12350365], dtype=float32),
#  ' SHOWCHAMPION  세븐틴   만세  SEVENTEEN   Man Sae  l EP 163  TWN ': array([0.49216002, 3.1647341 , 0.83488446, ..., 0.5440358 , 0.21043727,
#         0.09671721], dtype=float32),
#  ' SHOWCHAMPION  마마무   1cm의 자존심   MAMAMOO   Taller than you   l EP 176  ENG FRA ': array([0.34257632, 1.6376296 , 0.4812701 , ..., 0.15889172, 0.7761159 ,
#         0.23642202], dtype=float32),
#  ' SHOWCHAMPION  여자친구   바람에 날려  GFRIEND   Gone with the Wind  l EP 194  TWN ': array([0.3083978 , 0.9534411 , 0.59921354, ..., 0.00596723, 0.1140799 ,
#         0.2523076 ], dtype=float32),
#  ' SHOWCHAMPION  여자친구   시간을 달려서  GFRIEND   Rough  l EP 171': array([0.07846857, 1.5249394 , 0.01402612, ..., 0.03798715, 0.501291  ,
#         0.04533176], dtype=float32),
#  ' SHOWCHAMPION  세븐틴   빠른 걸음  SEVENTEEN   Fast Pace  l EP 209': array([0.03719172, 1.5081564 , 0.4578373 , ..., 0.00893073, 0.3924707 ,
#         0.10053669], dtype=float32),
#  ' 아시아나항공  여행이 떠났다': array([0.84634024, 0.5361139 , 0.61138666, ..., 0.05660483, 0.2793129 ,
#         0.05762925], dtype=float32),
#  '아시아나항공 CHICAGO 편': array([0.6698105 , 0.00225771, 0.00938664, ..., 0.12589636, 0.0787889 ,
#         0.06837666], dtype=float32),
#  '뉴욕과 더 가까워지는 아시아나항공_매일 2회 운항': array([0.01137666, 1.3482641 , 0.09631555, ..., 0.02610574, 0.1164218 ,
#         0.12173998], dtype=float32),
#  '아시아나항공  뉴욕 캠페인 ASIANA350 편': array([0.01178113, 0.8818434 , 0.2917519 , ..., 0.01884726, 0.33717063,
#         0.16699927], dtype=float32),
#  '2015 Asiana Airlines Global CF_Fly with Color  Matthew Kepnes ': array([0.00132217, 0.95282143, 0.40495238, ..., 0.29773244, 0.13118386,
#         0.0041362 ], dtype=float32),
#  '아시아나항공 AROUND THE USA': array([0.08837312, 1.4580739 , 0.34763035, ..., 0.13640466, 0.08003799,
#         0.11852904], dtype=float32),
#  '아시아나항공 신규취항_가오슝_편안함 편': array([0.2652981 , 0.5924331 , 0.58684623, ..., 0.08410972, 0.05521537,
#         0.18038978], dtype=float32),
#  '아시아나항공 신규취항_가오슝_넉넉함 편': array([0.7179511 , 0.7263316 , 1.6407706 , ..., 0.20313528, 0.1592017 ,
#         0.63406634], dtype=float32),
#  'ASIANA350 미서부 3개 도시 운항   시애틀편': array([0.11570307, 0.46702284, 0.2871337 , ..., 0.22619736, 0.23000602,
#         0.08949248], dtype=float32),
#  '아시아나가 Pick 한 프랑크푸르트 Top Pick': array([0.17687418, 1.1822234 , 0.08697805, ..., 0.01706914, 0.1046465 ,
#         0.22215413], dtype=float32),
#  'ASIANA350 미서부 3개 도시 운항   샌프란시스코편': array([0.34937423, 2.2955403 , 0.6108904 , ..., 0.2000702 , 0.45111057,
#         0.2400199 ], dtype=float32),
#  'ASIANA350 미서부 3개 도시 운항   로스앤젤레스편': array([0.01310816, 0.93365157, 0.49446726, ..., 0.04480588, 0.12695934,
#         0.23069733], dtype=float32),
#  '아시아나항공 I m Barcelona   바르셀로네따': array([0.34757555, 0.52740926, 0.51863426, ..., 0.        , 0.03266231,
#         0.45716587], dtype=float32),
#  '2017 Asiana Airlines  To Seoul and Beyond ': array([0.64753896, 0.34526604, 0.9699489 , ..., 0.03288547, 0.42107707,
#         0.18535186], dtype=float32),
#  '아시아나항공 I m Barcelona   몬주익 분수': array([0.01642571, 0.6423767 , 1.1486121 , ..., 0.12233741, 0.1354369 ,
#         0.12306106], dtype=float32),
#  '아시아나항공 I m Barcelona   구엘 공원': array([0.00950908, 0.09677307, 0.27043492, ..., 0.26742437, 0.8794367 ,
#         0.22585677], dtype=float32),
#  '아시아나항공 VENICE IN A DAY   8 40 p m  편': array([0.04404018, 0.53534275, 0.04134798, ..., 0.34860852, 0.17204921,
#         0.00892455], dtype=float32),
#  '아시아나항공 VENICE IN A DAY   12 20 p m  편': array([0.44032755, 0.07297235, 0.3661204 , ..., 0.3543101 , 0.9079534 ,
#         0.14347796], dtype=float32),
#  '아시아나항공 I m Barcelona   바르셀로나 바': array([0.3866928 , 1.7923478 , 0.644799  , ..., 0.02655425, 0.07408672,
#         0.04661644], dtype=float32),
#  'Welcome to ASIANA350': array([1.301781  , 0.55557376, 0.89631927, ..., 0.2784585 , 2.4839675 ,
#         0.7989265 ], dtype=float32),
#  '빅토리아 시대 방식으로 버터 만들기': array([0.44347966, 0.8581015 , 0.93315995, ..., 0.1938382 , 1.2892504 ,
#         1.8454313 ], dtype=float32),
#  'Queen Elizabeth I Makeup Tutorial   History Inspired   Feat  Amber Butchart and Rebecca Butterworth': array([0.5434871 , 3.511966  , 1.0113827 , ..., 1.5176363 , 0.30925053,
#         0.10581191], dtype=float32),
#  '빅토리안 방식으로 커스타드 푸딩 만드는 법': array([0.5525754 , 0.35718712, 1.6352469 , ..., 0.16857281, 0.22799426,
#         1.2813692 ], dtype=float32),
#  'How to Make Trifle   The Victorian Way': array([0.35549963, 1.5091305 , 0.48782894, ..., 0.18406956, 0.1603053 ,
#         0.46574286], dtype=float32),
#  '빅토리아 시대 방식으로 크리스마스 케이크 만들기': array([0.20091471, 1.2649893 , 1.0326697 , ..., 0.12166366, 0.600853  ,
#         0.64050376], dtype=float32),
#  '빅토리아 시대 방식으로 아이스크림 만들기': array([0.29096705, 0.5819875 , 1.5268022 , ..., 0.11716618, 0.39192644,
#         0.46600544], dtype=float32),
#  '빅토리아 시대 방식으로 아침식사 만들기': array([0.35179543, 0.60902333, 1.0670155 , ..., 0.5042832 , 0.40107766,
#         0.44415906], dtype=float32),
#  '빅토리아 시대 방식으로 팬케이크 만들기': array([0.15579328, 0.7398965 , 0.6851099 , ..., 0.3975489 , 0.48988613,
#         0.515308  ], dtype=float32),
#  '빅토리아 시대 방식으로 빅토리아 샌드위치 만들기': array([0.22708748, 0.92074966, 0.36897278, ..., 0.2982681 , 0.351637  ,
#         0.2962123 ], dtype=float32),
#  'How to Make Marmalade Water Ice   The Victorian Way': array([0.3857489 , 0.41989365, 0.7327738 , ..., 0.26421756, 1.112499  ,
#         0.7685684 ], dtype=float32),
#  'How to Make Chocolate Pudding   The Victorian Way': array([0.4045954, 1.5722946, 1.7691844, ..., 0.3127746, 1.1717309,
#         0.7753789], dtype=float32),
#  'How to Make Soup   The Victorian Way': array([0.28285462, 1.0629325 , 0.8129872 , ..., 0.27113265, 0.82781136,
#         0.4965989 ], dtype=float32),
#  'How to Make Pigeon Pie   The Victorian Way': array([0.3395679 , 1.221697  , 0.75024855, ..., 0.46017838, 0.70369977,
#         0.31810564], dtype=float32),
#  '가난한 사람들을위한 스프 만드는 법   빅토리아 방식': array([0.16868034, 0.70548296, 0.50071156, ..., 0.2656207 , 0.5523378 ,
#         0.32879052], dtype=float32),
#  'How to Make Marbled Eggs for Easter   The Victorian Way': array([0.12744404, 0.54064846, 0.762367  , ..., 0.2279789 , 0.33353692,
#         0.5310001 ], dtype=float32),
#  'Queen Victoria Makeup Tutorial   History Inspired   Feat  Amber Butchart and Rebecca Butterworth': array([0.8379451 , 1.5149475 , 2.118908  , ..., 0.43349206, 0.16486289,
#         0.03298008], dtype=float32),
#  'Behind The Scenes With Kathy Hipperson  Mrs Crocombe ': array([0.1489491 , 1.8820181 , 1.3021773 , ..., 0.13215335, 1.1754599 ,
#         0.57421637], dtype=float32),
#  'How to Cook Turkey   The Victorian Way': array([0.21040955, 0.340588  , 1.1325705 , ..., 0.02185996, 0.9097139 ,
#         0.4843803 ], dtype=float32),
#  'How to Cook Turbot   The Victorian Way': array([0.38293123, 0.8063654 , 0.6770752 , ..., 0.34660387, 1.1327705 ,
#         0.33094287], dtype=float32),
#  '    1 연락처를 교환했는데 알고보니 홍콩연예인  ': array([0.34470877, 1.7641755 , 1.2285178 , ..., 0.39258954, 0.844035  ,
#         0.15579683], dtype=float32),
#  '태어나 한국 휴게소 처음 가본 홍콩 연예인 여사친의 반응  ': array([0.65026474, 2.717297  , 0.5368594 , ..., 0.20336068, 0.72855735,
#         0.3428166 ], dtype=float32),
#  '   대만  시골 대학교 에 학식 먹으러 갔다가 생긴 일  반전주의 ': array([0.41680053, 2.082495  , 1.646705  , ..., 0.18455552, 0.52037656,
#         0.01912742], dtype=float32),
#  ' 3  태국  국경지대에 살고 있는 여사친네 집에 가기 뜻밖에 라오스 빈민가에서의 하루 마지막이야기 ': array([0.13848805, 0.8834271 , 1.5868285 , ..., 0.1287077 , 0.28842962,
#         0.16683559], dtype=float32),
#  '   대만 여행하다  에일리 닮은  일본 스튜어디스와 친구가 된 사연': array([0.47342148, 1.2500906 , 1.1200495 , ..., 0.07152748, 0.44125763,
#         0.05435039], dtype=float32),
#  '    홍콩 마카오 여행 하다 버스안에서 생긴 일  중국사람이   ': array([0.02451351, 1.6802408 , 0.7347089 , ..., 0.10157508, 0.15792045,
#         0.17167786], dtype=float32),
#  '길에서 처음 만난 외국인을 자신의 집으로 초대하는 태국 여성들  with BJ갓성은이 나를 찾아왔다 ': array([0.37873787, 1.9801701 , 1.1181885 , ..., 0.13403141, 0.6879252 ,
#         0.31204304], dtype=float32),
#  '   2화  베트남 수상한 그녀들    집에 따라가게 된 사연': array([0.29582858, 1.2516859 , 0.63563764, ..., 0.5065651 , 1.8848914 ,
#         0.7521502 ], dtype=float32),
#  '   1화  베트남 수상한 그녀들    집에 따라가게 된 사연': array([0.06898937, 2.2705395 , 0.81659037, ..., 0.19442102, 0.39658836,
#         0.15184706], dtype=float32),
#  '태국  버스킹에 난입해 k pop스타 출신 숨기고 한국 노래 불렀더니 반응이  ': array([0.06543678, 1.7616001 , 0.40540928, ..., 0.03725333, 0.3092453 ,
#         0.11162252], dtype=float32),
#  '   길에서 만나  갑자기 노래방 가게 되었어요': array([0.4016504, 2.5487134, 2.368597 , ..., 0.5728786, 0.5071544,
#         0.1728358], dtype=float32),
#  '미스 유니버스  모델이 먼저 헌팅하는 나라   여행 중 야시장에서 혼술 하다 생긴 일': array([0.3287726 , 1.3533317 , 1.1037894 , ..., 0.19069067, 0.6077433 ,
#         0.24429639], dtype=float32),
#  '   대만에서 한국노래를 불렀을때  대만 여성분의 반응은 ': array([0.44005483, 2.0393343 , 1.6909149 , ..., 0.38760367, 0.4565158 ,
#         0.4866023 ], dtype=float32),
#  '갑자기 k pop 불렀더니 태국   여대생들의 반응 ': array([0.4065648 , 1.6023966 , 2.0956957 , ..., 0.27429172, 0.2769382 ,
#         0.4329451 ], dtype=float32),
#  ' 1  태국  국경지대에 살고 있는 여사친네 집에 가기 가정집 방문 ': array([0.35887456, 1.34183   , 1.4262908 , ..., 0.46554142, 0.73642   ,
#         0.06408448], dtype=float32),
#  '   ep2 대만 여사친이  2번째 만남에  자신의 아빠 를 만나자는 의미는   뜻밖에 사위  ': array([0.5184659 , 1.261235  , 1.9008219 , ..., 0.07802796, 0.6268328 ,
#         0.29604688], dtype=float32),
#  '   3화  베트남 수상한 그녀들    집에 따라가게 된 사연': array([0.00833243, 1.9215907 , 1.186813  , ..., 0.08466203, 0.40435195,
#         0.27649468], dtype=float32),
#  '남자 혼자 1박2일 여성 자전거 모임에 나가면 생기는 일': array([0.272428  , 2.2082632 , 0.5803102 , ..., 0.03737881, 0.21261723,
#         0.26385465], dtype=float32),
#  '  ep6  길에서 친구가 된 홍콩연예인이 만난지 2틀만에  핸드폰 선물 을  ': array([0.19245823, 1.6824957 , 1.7617664 , ..., 0.20975572, 0.48470518,
#         0.1401964 ], dtype=float32),
#  '  연변에서 조선족에게 가장 유명하다는 리치클럽 저녁에 가도 안전할까 ': array([0.10075052, 1.3699517 , 0.27279586, ..., 0.23760934, 0.11937425,
#         0.13637646], dtype=float32),
#  '막걸리 처음 먹어 본다는 대만에서 온 한국 여동생': array([0.26264188, 0.31435966, 0.29450938, ..., 0.07212638, 0.595969  ,
#         0.08921897], dtype=float32),
#  '   음료사러 갔는데 돈을 안받는다고 합니다  이유가 잘생겨서  ': array([0.340939  , 2.3472161 , 1.6012707 , ..., 0.25768638, 0.6891236 ,
#         0.31968203], dtype=float32),
#  '   태국  미얀마 국경지역에서 온천에 가 보았습니다  그리고 시골 클럽에서   ': array([0.03813839, 0.69899803, 0.48953682, ..., 0.18961692, 0.66728216,
#         0.13631997], dtype=float32),
#  '방송 출연 5분만에 시청자 떡상시키고 인터뷰 중단하게 된 태국미녀': array([0.2926502 , 1.5569935 , 0.93847877, ..., 0.25268984, 0.7193501 ,
#         0.32289073], dtype=float32),
#  'Enjoy your Creative Korea   Official TVC for 2016 Korea Tourism   60s': array([0.44016016, 0.41846728, 1.2466813 , ..., 0.00701869, 0.10321628,
#         0.01501386], dtype=float32),
#  'Feel the Rhythm of KOREA  BUSAN': array([0.04038236, 1.270674  , 0.1326101 , ..., 0.00862535, 0.26576287,
#         0.06416577], dtype=float32),
#  'Feel the Rhythm of Korea  SEOUL': array([0.18776473, 0.06895172, 0.40823373, ..., 0.01534394, 0.3846079 ,
#         0.19445743], dtype=float32),
#  'Feel the Rhythm of KOREA  JEONJU': array([0.0756311 , 0.06763002, 0.7693842 , ..., 0.11021172, 0.34010294,
#         0.31793815], dtype=float32),
#  'Rhythm of Adventure': array([0.04360218, 1.0432509 , 1.0363182 , ..., 0.18689647, 0.17730033,
#         0.10811913], dtype=float32),
#  'Rhythm of Light': array([0.05085721, 1.47129   , 0.8395986 , ..., 0.159914  , 0.663071  ,
#         0.05246803], dtype=float32),
#  'Rhythm of Taste': array([0.181559  , 1.3704518 , 0.989502  , ..., 0.27673888, 0.3838795 ,
#         0.09269799], dtype=float32),
#  'Rhythm of K Beauty': array([0.70460415, 1.6338087 , 1.2482029 , ..., 0.18200633, 0.31475043,
#         0.06304216], dtype=float32),
#  'Rhythm of Healing': array([0.0787185 , 0.9042145 , 1.0233214 , ..., 0.19571882, 0.42047638,
#         0.14285338], dtype=float32),
#  'Rhythm of Vibes': array([0.04994191, 0.7225187 , 1.0417922 , ..., 0.19660084, 0.5886496 ,
#         0.42229462], dtype=float32),
#  ' Trải nghiệm phiêu lưu mạo hiểm X hàn Quốc kỳ thú ': array([0.34197262, 1.1375893 , 0.87805784, ..., 0.10106762, 0.530686  ,
#         0.20320727], dtype=float32),
#  'Feel the Rhythm of KOREA  GANGNEUNG': array([0.03420826, 0.2034886 , 0.039234  , ..., 0.03435373, 0.66458046,
#         0.07180119], dtype=float32),
#  ' Du lịch cùng bé yêu X Vui chơi thỏa thích ở Hàn Quốc ': array([0.02277603, 1.0069609 , 0.2521261 , ..., 0.16272852, 0.54034275,
#         0.03783293], dtype=float32),
#  'Korea Winter TVC   Draw your winter story in PyeongChang 2018': array([0.21317399, 1.9816843 , 0.75817925, ..., 0.0516371 , 0.37236997,
#         0.2910199 ], dtype=float32),
#  ' Capturing Korea  Film 3   Personality  Jejudo  30  ': array([0.04310559, 1.0090934 , 0.26811847, ..., 0.35034782, 0.13436313,
#         0.08785706], dtype=float32),
#  '  KTO X EXO TVC  Korean History   Tradition  VT   ': array([0.2508769 , 0.12527256, 2.1884332 , ..., 0.41333374, 0.39716113,
#         0.11976165], dtype=float32),
#  'Feel the Rhythm of KOREA  MOKPO': array([0.19578439, 0.42885956, 0.87991136, ..., 0.09780261, 0.07825217,
#         0.078936  ], dtype=float32),
#  'Feel the Rhythm of KOREA  ANDONG': array([0.2639529 , 0.6465343 , 0.20011134, ..., 0.12293946, 0.68737406,
#         0.02517258], dtype=float32),
#  ' Capturing Korea  Film 2   Colour  Busan  30  ': array([0.44171578, 0.748042  , 0.30577803, ..., 0.11525325, 0.16746037,
#         0.17369205], dtype=float32),
#  ' Can you Imagine  You X Playful Korea ': array([0.18068415, 0.89701974, 0.3629158 , ..., 0.08189946, 0.5740742 ,
#         0.08731236], dtype=float32),
#  ' Can you Imagine  You X Breathtaking Korea ': array([0.21781668, 0.29916492, 1.4300525 , ..., 0.14581816, 0.27582976,
#         0.03607057], dtype=float32),
#  '  KTO X EXO TVC  Korean   style Healing  THAI   ': array([0.04474586, 0.69397783, 0.4442468 , ..., 0.1735443 , 0.31900427,
#         0.15313119], dtype=float32),
#  '1년이라도 아이들 옆에 있고 싶어 시작한 여행_달려라 미니버스  빼빼가족 유라시아 여행기': array([0.16413364, 0.2436671 , 0.14982766, ..., 0.02345636, 0.58581597,
#         0.24210243], dtype=float32),
#  '걸어서 세계속으로   걸어서 평양속으로  2018 09 15 방송 ': array([0.15266733, 2.169836  , 0.15961607, ..., 0.3362868 , 0.26359725,
#         0.0317038 ], dtype=float32),
#  '핀란드의 군사 도시  하미나에서 일으킨 돌풍  국방부 전통악대  2018 ': array([0.06395989, 0.34003043, 0.5590653 , ..., 0.0927963 , 0.48919755,
#         0.1226634 ], dtype=float32),
#  '노량진  컵밥 으로 매출 300억  푸드 트럭의 역사를 새로 쓴 유학생 3인방 이야기': array([0.00591352, 0.8920894 , 0.13891952, ..., 0.13604437, 0.26539877,
#         0.3360584 ], dtype=float32),
#  ' ENG  슬로베니아에서 살아보기 3회_키즈카페에서 부르는 정인의  오르막길': array([0.12898882, 1.0652363 , 0.8130977 , ..., 0.20188336, 0.5595283 ,
#         0.18098393], dtype=float32),
#  ' K Colombia Travel Cartagena 콜롬비아 여행 카르타헤나 토투모 화산 머드체험 Cartagena Totumo Volcano Mud Experience': array([0.30926204, 1.4312155 , 0.245911  , ..., 0.5254578 , 0.271273  ,
#         0.8130649 ], dtype=float32),
#  '세계문화유산 탐험 40편_지구상 가장 비밀스러운 장소였던 세계 최대의 궁전  자금성': array([0.20576453, 0.20971633, 0.5271366 , ..., 0.08979305, 0.03786432,
#         0.23933297], dtype=float32),
#  '세계문화유산 탐험 2편_잉카인들은 마추픽추를 버리고 어디로 사라졌나': array([0.00988803, 0.774302  , 0.03035865, ..., 0.10660191, 0.1546734 ,
#         0.18229572], dtype=float32),
#  '세계문화유산 탐험 20편_바위 10미터 아래 지하무덤에서 발굴된 석관에서 알파벳의 기원  페니키아 문자가 발견됐다  레바논 고대유적  비블로스와 바알베크': array([0.04163453, 0.60039425, 0.03504961, ..., 0.1261545 , 0.1615785 ,
#         0.11959393], dtype=float32),
#  ...}

# %%
import base64
import io
from PIL import Image
import cv2
import numpy as np

# %%
data="data:image/png;base64,..."

# %%
splitIndex = data.find(',')

# %%
data = data[splitIndex+1:]

# %%
data
# Out:
# '...'

# %%
def stringToRGB(base64_string):
    imgdata = base64.b64decode(base64_string)
    dataBytesIO = io.BytesIO(imgdata)
    image = Image.open(dataBytesIO)
    image = image.convert('RGB')
    return image

# %%
im = stringToRGB(data)

# %%
im
# Out:
# <PIL.Image.Image image mode=RGB size=266x143 at 0x26B3BBCBA30>

# %%
np.array(im).shape
# Out:
# (143, 266, 3)

# %%
transformationForCNNInput = transforms.Compose([transforms.Resize((224,224))])

upImgData = {}
testIm = transformationForCNNInput(im)
vec = img2vec.getVec(testIm)
upImgData['newImage'] = vec

# %%
upImgData
# Out:
# {'newImage': array([1.3436809 , 0.98030883, 0.869027  , ..., 0.04402817, 0.04767422,
#         0.55138814], dtype=float32)}

# %%
v1 = np.array(list(allVectors.values()))
v2 = np.array(list(upImgData.values()))
sim_ = cosine_similarity(v1,v2)
idx_keys = list(allVectors.keys())
col_keys = list(upImgData.keys())

# %%
idx_key
# Out:
# ['newImage']

# %%
v1.shape
# Out:
# (1752, 2048)

# %%
v2.shape
# Out:
# (1, 2048)

# %%
sim_.shape
# Out:
# (1752, 1)

# %%
matrix_ = pd.DataFrame(idx_keys,columns=['title'])
matrix_['similarity']= sim_
matrix_
# Out:
#                                                title  similarity
# 0               김경재  박근혜 구하기   삼성 출연금 8천억  노무현이 해먹었다    0.612738
# 1                  가수 최정철 일병   나미  모자 母子 가 한 무대에서 노래    0.521273
# 2          주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나     0.591539
# 3            트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다    0.639261
# 4                       남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑     0.661544
# ...                                              ...         ...
# 1747                    꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다    0.599304
# 1748               1회에 53만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래     0.604347
# 1749              120색 섀도우 66색 립스틱으로 풀메이크업 해봤다 코스탈센츠    0.627448
# 1750  포에버21화장품으로 풀메이크업 해봤다 Foever21 makeup challenge    0.723412
# 1751                       엘프 코스프레 메이크업   エルフコスプレメイク    0.538618
#
# [1752 rows x 2 columns]

# %%
df_new[['title','imgAdr']]
# Out:
#                                                title  \
# 0               김경재  박근혜 구하기   삼성 출연금 8천억  노무현이 해먹었다
# 1                  가수 최정철 일병   나미  모자 母子 가 한 무대에서 노래
# 2          주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나
# 3            트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다
# 4                       남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑
# ...                                              ...
# 1747                    꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다
# 1748               1회에 53만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래
# 1749              120색 섀도우 66색 립스틱으로 풀메이크업 해봤다 코스탈센츠
# 1750  포에버21화장품으로 풀메이크업 해봤다 Foever21 makeup challenge
# 1751                       엘프 코스프레 메이크업   エルフコスプレメイク
#
#                                                  imgAdr
# 0     https://i.ytimg.com/vi/lY1vCa4rDyg/hqdefault.j...
# 1     https://i.ytimg.com/vi/uZK2JDokRKs/hqdefault.j...
# 2     https://i.ytimg.com/vi/Myxpe_D-Qp8/hqdefault.j...
# 3     https://i.ytimg.com/vi/S_vIEkgvsB4/hqdefault.j...
# 4     https://i.ytimg.com/vi/ZNycCeuKUnw/hqdefault.j...
# ...                                                 ...
# 1747  https://i.ytimg.com/vi/MG9u6QdYOuA/hqdefault.j...
# 1748  https://i.ytimg.com/vi/VKiVHjA-rEE/hqdefault.j...
# 1749  https://i.ytimg.com/vi/uZYUMx7hfdY/hqdefault.j...
# 1750  https://i.ytimg.com/vi/COwUche5-8g/hqdefault.j...
# 1751  https://i.ytimg.com/vi/LtnsRJtNoi0/hqdefault.j...
#
# [1752 rows x 2 columns]

# %%
df_result = pd.merge(df_new[['title','imgAdr']],matrix_,left_on='title',right_on='title',how='inner')

# %%
df_result = df_result.sort_values(ascending=False , by="similarity")

# %%
for i in df_result.imgAdr[:5]:
    fd = urllib.request.urlopen(i)
    image_file = io.BytesIO(fd.read())
    im = Image.open(image_file)
    im.show()

# %%
matrix_ = matrix_.sort_values(ascending=False , by="newImage")

# %%
matrix_.index[:10]
# Out:
# Index([' 관훈라이트   116 1 손석희와 JTBC는 왜 그럴까',
#        '세계문화유산 탐험 35편_천 년 동안 화산재에 묻혀있던 세계 최대의 불교사원  인도네시아 보로부두르',
#        '한국 불매운동 단3주만에 일본제품 매출 절반으로 급락   아마 전세계에서 대한민국에서만 가능한 일 ',
#        '  다다뷰티  NEW 코덕들 맴찢 영상  화장품 부시기',
#        '미국이 방위비 압박하자 한국이 최신예 전력들을 발표해버린 현상황   유럽최강의 전력까지 탑재  압도적인 국방력으로 대답한 한국 ',
#        '인도네시아가 일본을 밀어내고 한국을 선택한 이유   세계인구 4위 인도네시아의 목숨을 구하는 한국의 기술력 ',
#        '설민석 강사님의 역사왜곡을 알아보자',
#        '  이게진짜될까    눈썹틴트   에뛰드하우스 브라우 젤 틴트로 예쁜 눈썹 문신이 될까    윤쨔미 메이크업',
#        '5부 한국에 일본보다 더 심한 장기 불황이 올 수밖에 없는 이유  쉬운경제   2018 06 26 ',
#        '세계문화유산 탐험 20편_바위 10미터 아래 지하무덤에서 발굴된 석관에서 알파벳의 기원  페니키아 문자가 발견됐다  레바논 고대유적  비블로스와 바알베크'],
#       dtype='object')

# %%
def getSimilarityMatrix(vectors):
    v = np.array(list(vectors.values()))
    sim = cosine_similarity(v, v)
    keys = list(vectors.keys())
    matrix = pd.DataFrame(sim, columns = keys, index = keys)
    
    return matrix
        
similarityMatrix = getSimilarityMatrix(allVectors)

# %%
similarityMatrix
# Out:
#                                                 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다  \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                        1.000000
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                           0.631998
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                    0.816713
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                     0.739806
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                                0.735514
# ...                                                                              ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                                0.624955
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                            0.610271
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                          0.633451
# 포에버  화장품으로 풀메이크업 해봤다                                                        0.631269
# 엘프 코스프레 메이크업                                                                0.642929
#
#                                                 가수 최정철 일병   나미  모자    가 한 무대에서 노래  \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                     0.631998
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                        1.000000
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                 0.615584
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                  0.680899
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                             0.652810
# ...                                                                           ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                             0.652917
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                         0.554538
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                       0.567666
# 포에버  화장품으로 풀메이크업 해봤다                                                     0.572642
# 엘프 코스프레 메이크업                                                             0.588740
#
#                                                 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나   \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                             0.816713
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                                0.615584
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                         1.000001
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                          0.716144
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                                     0.694673
# ...                                                                                   ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                                     0.633535
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                                 0.647922
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                               0.613659
# 포에버  화장품으로 풀메이크업 해봤다                                                             0.606767
# 엘프 코스프레 메이크업                                                                     0.627413
#
#                                                 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다  \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                           0.739806
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                              0.680899
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                       0.716144
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                        1.000000
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                                   0.796835
# ...                                                                                 ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                                   0.713808
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                               0.678106
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                             0.694320
# 포에버  화장품으로 풀메이크업 해봤다                                                           0.665726
# 엘프 코스프레 메이크업                                                                   0.682699
#
#                                                  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑   \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                 0.735514
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                    0.652810
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                             0.694673
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                              0.796835
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                         1.000000
# ...                                                                       ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                         0.674987
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                     0.709416
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                   0.631554
# 포에버  화장품으로 풀메이크업 해봤다                                                 0.733363
# 엘프 코스프레 메이크업                                                         0.611464
#
#                                                 불여우 따라간 한우마을 묻지마 관광  \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                       0.716587
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                          0.602338
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                   0.666664
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                    0.762782
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                               0.758156
# ...                                                             ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                               0.595538
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                           0.604809
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                         0.605104
# 포에버  화장품으로 풀메이크업 해봤다                                       0.617258
# 엘프 코스프레 메이크업                                               0.550437
#
#                                                  유엔참전용사 추모 음악회  국악인 김영임   경기민요 메들리               \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                                   0.768555
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                                      0.692071
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                               0.705094
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                                0.769752
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                                           0.781430
# ...                                                                                         ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                                           0.611644
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                                       0.614485
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                                     0.625354
# 포에버  화장품으로 풀메이크업 해봤다                                                                   0.632846
# 엘프 코스프레 메이크업                                                                           0.599928
#
#                                                 어머니뻘 시민 짓밟고 패륜적 욕설 퍼붇는 폭력범을 뻔히 보며 방관  \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                        0.679021
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                           0.605267
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                    0.687007
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                     0.698614
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                                0.710309
# ...                                                                              ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                                0.589731
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                            0.636533
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                          0.587919
# 포에버  화장품으로 풀메이크업 해봤다                                                        0.592009
# 엘프 코스프레 메이크업                                                                0.592169
#
#                                                 여군 헌병 순찰소대장 위풍당당                                     \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                                     0.651059
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                                        0.562198
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                                 0.619872
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                                  0.706807
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                                             0.635761
# ...                                                                                           ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                                             0.554517
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                                         0.563193
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                                       0.568666
# 포에버  화장품으로 풀메이크업 해봤다                                                                     0.533885
# 엘프 코스프레 메이크업                                                                             0.544184
#
#                                                 김동규    월의 어느 멋진 날에                                                  \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                                     0.755275
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                                        0.610628
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                                 0.693493
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                                  0.710424
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                                             0.725117
# ...                                                                                           ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                                             0.588087
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                                         0.579912
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                                       0.585351
# 포에버  화장품으로 풀메이크업 해봤다                                                                     0.581803
# 엘프 코스프레 메이크업                                                                             0.554036
#
#                                                 ...  \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다            ...
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래               ...
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나        ...
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다         ...
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                    ...
# ...                                             ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                    ...
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                ...
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠              ...
# 포에버  화장품으로 풀메이크업 해봤다                            ...
# 엘프 코스프레 메이크업                                    ...
#
#                                                 헬로키티 화장품으로 풀메이크업 해 봤다            \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                   0.628353
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                      0.627917
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                               0.615815
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                0.727825
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                           0.699946
# ...                                                                         ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                           0.865844
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                       0.736568
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                     0.736739
# 포에버  화장품으로 풀메이크업 해봤다                                                   0.750780
# 엘프 코스프레 메이크업                                                           0.753333
#
#                                                 세상에서 제일 비싼   만원짜리 자석팩              \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                     0.649976
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                        0.554028
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                 0.659093
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                  0.718028
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                             0.693972
# ...                                                                           ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                             0.733250
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                         0.678154
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                       0.682948
# 포에버  화장품으로 풀메이크업 해봤다                                                     0.725869
# 엘프 코스프레 메이크업                                                             0.634188
#
#                                                 제 돈     만원  쓴 단골 네일샵 을 소개합니다  \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                0.658140
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                   0.666465
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                            0.639364
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                             0.740702
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                        0.761676
# ...                                                                      ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                        0.804034
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                    0.732388
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                  0.736598
# 포에버  화장품으로 풀메이크업 해봤다                                                0.790960
# 엘프 코스프레 메이크업                                                        0.714802
#
#                                                 미국의 초저렴이 화장품     코스메틱으로 풀메이크업 해 봤다            \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                                0.661074
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                                   0.593166
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                            0.614686
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                             0.690564
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                                        0.646476
# ...                                                                                      ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                                        0.780507
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                                    0.682807
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                                  0.719035
# 포에버  화장품으로 풀메이크업 해봤다                                                                0.716895
# 엘프 코스프레 메이크업                                                                        0.723678
#
#                                                 세상에서 제일 비싼   만원짜리 립스틱 리뷰  크리스찬 루부탱                      \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                                     0.663312
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                                        0.629314
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                                 0.671312
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                                  0.726793
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                                             0.747479
# ...                                                                                           ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                                             0.844379
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                                         0.766564
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                                       0.696052
# 포에버  화장품으로 풀메이크업 해봤다                                                                     0.777141
# 엘프 코스프레 메이크업                                                                             0.785379
#
#                                                 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다  \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                0.624955
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                   0.652917
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                            0.633535
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                             0.713808
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                        0.674987
# ...                                                                      ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                        1.000000
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                    0.753823
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                  0.722376
# 포에버  화장품으로 풀메이크업 해봤다                                                0.733587
# 엘프 코스프레 메이크업                                                        0.753930
#
#                                                  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래   \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                     0.610271
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                        0.554538
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                 0.647922
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                  0.678106
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                             0.709416
# ...                                                                           ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                             0.753823
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                         1.000000
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                       0.627008
# 포에버  화장품으로 풀메이크업 해봤다                                                     0.687624
# 엘프 코스프레 메이크업                                                             0.633269
#
#                                                    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠  \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                      0.633451
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                         0.567666
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                  0.613659
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                   0.694320
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                              0.631554
# ...                                                                            ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                              0.722376
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                          0.627008
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                        1.000000
# 포에버  화장품으로 풀메이크업 해봤다                                                      0.726397
# 엘프 코스프레 메이크업                                                              0.660824
#
#                                                 포에버  화장품으로 풀메이크업 해봤다                            \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                                  0.631269
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                                     0.572642
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                              0.606767
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                               0.665726
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                                          0.733363
# ...                                                                                        ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                                          0.733587
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                                      0.687624
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                                    0.726397
# 포에버  화장품으로 풀메이크업 해봤다                                                                  1.000000
# 엘프 코스프레 메이크업                                                                          0.658820
#
#                                                 엘프 코스프레 메이크업
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                             0.642929
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                0.588740
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                         0.627413
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                          0.682699
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                     0.611464
# ...                                                                   ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                     0.753930
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                 0.633269
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                               0.660824
# 포에버  화장품으로 풀메이크업 해봤다                                             0.658820
# 엘프 코스프레 메이크업                                                     1.000000
#
# [1689 rows x 1689 columns]

# %%
from numpy.testing import assert_almost_equal
import pickle

k = 5 # the number of top similar images to be stored

similarNames = pd.DataFrame(index = similarityMatrix.index, columns = range(k))
similarValues = pd.DataFrame(index = similarityMatrix.index, columns = range(k))

for j in tqdm(range(similarityMatrix.shape[0])):
    kSimilar = similarityMatrix.iloc[j, :].sort_values(ascending = False).head(k)
    similarNames.iloc[j, :] = list(kSimilar.index)
    similarValues.iloc[j, :] = kSimilar.values
    
similarNames.to_pickle("similarNames.pkl")
similarValues.to_pickle("similarValues.pkl")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 1689/1689 [00:01<00:00, 1003.86it/s]

# %%
len(similarityMatrix)
# Out:
# 1689

# %%
similarityMatrix
# Out:
#                                                 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다  \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                        1.000000
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                           0.631998
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                    0.816713
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                     0.739806
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                                0.735514
# ...                                                                              ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                                0.624955
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                            0.610271
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                          0.633451
# 포에버  화장품으로 풀메이크업 해봤다                                                        0.631269
# 엘프 코스프레 메이크업                                                                0.642929
#
#                                                 가수 최정철 일병   나미  모자    가 한 무대에서 노래  \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                     0.631998
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                        1.000000
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                 0.615584
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                  0.680899
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                             0.652810
# ...                                                                           ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                             0.652917
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                         0.554538
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                       0.567666
# 포에버  화장품으로 풀메이크업 해봤다                                                     0.572642
# 엘프 코스프레 메이크업                                                             0.588740
#
#                                                 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나   \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                             0.816713
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                                0.615584
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                         1.000001
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                          0.716144
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                                     0.694673
# ...                                                                                   ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                                     0.633535
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                                 0.647922
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                               0.613659
# 포에버  화장품으로 풀메이크업 해봤다                                                             0.606767
# 엘프 코스프레 메이크업                                                                     0.627413
#
#                                                 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다  \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                           0.739806
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                              0.680899
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                       0.716144
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                        1.000000
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                                   0.796835
# ...                                                                                 ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                                   0.713808
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                               0.678106
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                             0.694320
# 포에버  화장품으로 풀메이크업 해봤다                                                           0.665726
# 엘프 코스프레 메이크업                                                                   0.682699
#
#                                                  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑   \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                 0.735514
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                    0.652810
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                             0.694673
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                              0.796835
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                         1.000000
# ...                                                                       ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                         0.674987
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                     0.709416
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                   0.631554
# 포에버  화장품으로 풀메이크업 해봤다                                                 0.733363
# 엘프 코스프레 메이크업                                                         0.611464
#
#                                                 불여우 따라간 한우마을 묻지마 관광  \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                       0.716587
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                          0.602338
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                   0.666664
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                    0.762782
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                               0.758156
# ...                                                             ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                               0.595538
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                           0.604809
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                         0.605104
# 포에버  화장품으로 풀메이크업 해봤다                                       0.617258
# 엘프 코스프레 메이크업                                               0.550437
#
#                                                  유엔참전용사 추모 음악회  국악인 김영임   경기민요 메들리               \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                                   0.768555
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                                      0.692071
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                               0.705094
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                                0.769752
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                                           0.781430
# ...                                                                                         ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                                           0.611644
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                                       0.614485
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                                     0.625354
# 포에버  화장품으로 풀메이크업 해봤다                                                                   0.632846
# 엘프 코스프레 메이크업                                                                           0.599928
#
#                                                 어머니뻘 시민 짓밟고 패륜적 욕설 퍼붇는 폭력범을 뻔히 보며 방관  \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                        0.679021
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                           0.605267
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                    0.687007
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                     0.698614
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                                0.710309
# ...                                                                              ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                                0.589731
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                            0.636533
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                          0.587919
# 포에버  화장품으로 풀메이크업 해봤다                                                        0.592009
# 엘프 코스프레 메이크업                                                                0.592169
#
#                                                 여군 헌병 순찰소대장 위풍당당                                     \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                                     0.651059
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                                        0.562198
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                                 0.619872
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                                  0.706807
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                                             0.635761
# ...                                                                                           ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                                             0.554517
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                                         0.563193
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                                       0.568666
# 포에버  화장품으로 풀메이크업 해봤다                                                                     0.533885
# 엘프 코스프레 메이크업                                                                             0.544184
#
#                                                 김동규    월의 어느 멋진 날에                                                  \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                                     0.755275
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                                        0.610628
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                                 0.693493
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                                  0.710424
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                                             0.725117
# ...                                                                                           ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                                             0.588087
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                                         0.579912
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                                       0.585351
# 포에버  화장품으로 풀메이크업 해봤다                                                                     0.581803
# 엘프 코스프레 메이크업                                                                             0.554036
#
#                                                 ...  \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다            ...
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래               ...
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나        ...
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다         ...
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                    ...
# ...                                             ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                    ...
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                ...
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠              ...
# 포에버  화장품으로 풀메이크업 해봤다                            ...
# 엘프 코스프레 메이크업                                    ...
#
#                                                 헬로키티 화장품으로 풀메이크업 해 봤다            \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                   0.628353
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                      0.627917
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                               0.615815
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                0.727825
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                           0.699946
# ...                                                                         ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                           0.865844
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                       0.736568
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                     0.736739
# 포에버  화장품으로 풀메이크업 해봤다                                                   0.750780
# 엘프 코스프레 메이크업                                                           0.753333
#
#                                                 세상에서 제일 비싼   만원짜리 자석팩              \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                     0.649976
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                        0.554028
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                 0.659093
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                  0.718028
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                             0.693972
# ...                                                                           ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                             0.733250
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                         0.678154
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                       0.682948
# 포에버  화장품으로 풀메이크업 해봤다                                                     0.725869
# 엘프 코스프레 메이크업                                                             0.634188
#
#                                                 제 돈     만원  쓴 단골 네일샵 을 소개합니다  \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                0.658140
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                   0.666465
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                            0.639364
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                             0.740702
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                        0.761676
# ...                                                                      ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                        0.804034
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                    0.732388
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                  0.736598
# 포에버  화장품으로 풀메이크업 해봤다                                                0.790960
# 엘프 코스프레 메이크업                                                        0.714802
#
#                                                 미국의 초저렴이 화장품     코스메틱으로 풀메이크업 해 봤다            \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                                0.661074
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                                   0.593166
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                            0.614686
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                             0.690564
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                                        0.646476
# ...                                                                                      ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                                        0.780507
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                                    0.682807
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                                  0.719035
# 포에버  화장품으로 풀메이크업 해봤다                                                                0.716895
# 엘프 코스프레 메이크업                                                                        0.723678
#
#                                                 세상에서 제일 비싼   만원짜리 립스틱 리뷰  크리스찬 루부탱                      \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                                     0.663312
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                                        0.629314
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                                 0.671312
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                                  0.726793
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                                             0.747479
# ...                                                                                           ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                                             0.844379
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                                         0.766564
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                                       0.696052
# 포에버  화장품으로 풀메이크업 해봤다                                                                     0.777141
# 엘프 코스프레 메이크업                                                                             0.785379
#
#                                                 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다  \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                0.624955
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                   0.652917
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                            0.633535
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                             0.713808
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                        0.674987
# ...                                                                      ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                        1.000000
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                    0.753823
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                  0.722376
# 포에버  화장품으로 풀메이크업 해봤다                                                0.733587
# 엘프 코스프레 메이크업                                                        0.753930
#
#                                                  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래   \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                     0.610271
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                        0.554538
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                 0.647922
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                  0.678106
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                             0.709416
# ...                                                                           ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                             0.753823
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                         1.000000
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                       0.627008
# 포에버  화장품으로 풀메이크업 해봤다                                                     0.687624
# 엘프 코스프레 메이크업                                                             0.633269
#
#                                                    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠  \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                      0.633451
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                         0.567666
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                  0.613659
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                   0.694320
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                              0.631554
# ...                                                                            ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                              0.722376
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                          0.627008
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                        1.000000
# 포에버  화장품으로 풀메이크업 해봤다                                                      0.726397
# 엘프 코스프레 메이크업                                                              0.660824
#
#                                                 포에버  화장품으로 풀메이크업 해봤다                            \
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                                                  0.631269
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                                     0.572642
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                                              0.606767
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                                               0.665726
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                                          0.733363
# ...                                                                                        ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                                          0.733587
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                                      0.687624
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                                                    0.726397
# 포에버  화장품으로 풀메이크업 해봤다                                                                  1.000000
# 엘프 코스프레 메이크업                                                                          0.658820
#
#                                                 엘프 코스프레 메이크업
# 김경재  박근혜 구하기   삼성 출연금  천억  노무현이 해먹었다                             0.642929
# 가수 최정철 일병   나미  모자    가 한 무대에서 노래                                0.588740
# 주부 이수미   호남의 빨갱이들은 뭉치는데 영남 애국시민은 왜 못 뭉치나                         0.627413
# 트로트 신동 황혜린  아리조나 카우보이  명국환 원로가수 앞에서 부르다                          0.682699
#  남인수 가요  트로트 신동 황혜린  꼬집힌 풋사랑                                     0.611464
# ...                                                                   ...
# 꽃잎 블러셔   라듀레 화장품으로 풀메이크업 해봤다                                     0.753930
#  회에   만원짜리 겔랑스파 피부관리는 도대체 뭘 해주길래                                 0.633269
#    색 섀도우   색 립스틱으로 풀메이크업 해봤다 코스탈센츠                               0.660824
# 포에버  화장품으로 풀메이크업 해봤다                                             0.658820
# 엘프 코스프레 메이크업                                                     1.000000
#
# [1689 rows x 1689 columns]

# %%
import matplotlib.pyplot as plt
    
# take three examples from the provided image set and plot
inputImages = ["1.jpg", "2.jpg", "3.jpg", "4.jpg"]

numCol = 5
numRow = 1

def setAxes(ax, image, query = False, **kwargs):
    value = kwargs.get("value", None)
    if query:
        ax.set_xlabel("Query Image\n{0}".format(image), fontsize = 12)
    else:
        ax.set_xlabel("similratiy {1:1.3f}\n{0}".format( image,  value), fontsize = 12)
    ax.set_xticks([])
    ax.set_yticks([])
    
def getSimilarImages(image, simNames, simVals):
    if image in set(simNames.index):
        imgs = list(simNames.loc[image, :])
        vals = list(simVals.loc[image, :])
        if image in imgs:
            assert_almost_equal(max(vals), 1, decimal = 5)
            imgs.remove(image)
            vals.remove(max(vals))
        return imgs, vals
    else:
        print("'{}' Unknown image".format(image))
        
def plotSimilarImages(image, simiarNames, similarValues):
    simImages, simValues = getSimilarImages(image, similarNames, similarValues)
    fig = plt.figure(figsize=(10, 20))
    
    # now plot the  most simliar images
    for j in range(0, numCol*numRow):
        ax = []
        if j == 0:
            img = Image.open(os.path.join(inputDir, image))
            ax = fig.add_subplot(numRow, numCol, 1)
            setAxes(ax, image, query = True)
        else:
            img = Image.open(os.path.join(inputDir, simImages[j-1]))
            ax.append(fig.add_subplot(numRow, numCol, j+1))
            setAxes(ax[-1], simImages[j-1], value = simValues[j-1])
        img = img.convert('RGB')
        plt.imshow(img)
        img.close()
    
    plt.show()
        
for image in inputImages:
    plotSimilarImages(image, similarNames, similarValues)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-d6f680293b9f> in <module>
#      50
#      51 for image in inputImages:
# ---> 52     plotSimilarImages(image, similarNames, similarValues)
#
# <ipython-input-81-d6f680293b9f> in plotSimilarImages(image, simiarNames, similarValues)
#      36         ax = []
#      37         if j == 0:
# ---> 38             img = Image.open(os.path.join(inputDir, image))
#      39             ax = fig.add_subplot(numRow, numCol, 1)
#      40             setAxes(ax, image, query = True)
#
# NameError: name 'inputDir' is not defined
