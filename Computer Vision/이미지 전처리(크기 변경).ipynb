# %%
from wand.image import Image
import os
import glob
import re
import numpy as np

# %%
Image(filename="https://i.ytimg.com/vi/lY1vCa4rDyg/hqdefault.jpg?sqp=-oaymwEZCNACELwBSFXyq4qpAwsIARUAAIhCGAFwAQ==&rs=AOn4CLDnioFyHd5bLF7C7zFPwFjychg9pQ")
# Out:
# <wand.image.Image: 2cd51f9 'WEBP' (336x188)>

# %%
os.getcwd() # 현재경로 확인
# Out:
# 'C:\\Users\\User\\Documents\\myproject\\Crawling'

# %%
animal = glob.glob(os.getcwd() + "./동물/동물/*.jpg")
beauti = glob.glob(os.getcwd() + "./뷰티/뷰티/*.jpg")
fashion = glob.glob(os.getcwd() + "./패션/패션/*.jpg")
kids = glob.glob(os.getcwd() + "./키즈/키즈/*.jpg")
game = glob.glob(os.getcwd() + "./게임/게임/*.jpg")
eating = glob.glob(os.getcwd() + "./먹방/먹방/*.jpg")

# %%
categoryList = [animal,beauti,fashion,kids,game,eating]

# %%
# 224 px * 244px 로 변경
for ca in categoryList:
    for imgPath in ca:
        img = Image(filename=imgPath)
        img.sample(224,224)
        img.save(filename=imgPath)

# %%
Image(filename="./12134.jpg")
# Out:
# <wand.image.Image: 72f311c 'WEBP' (336x188)>

# %%
import base64
with open('./12134.jpg', 'rb') as img:
    base64_string1 = base64.b64encode(img.read())

# %%
base64_string1
# Out:
# b'...'

# %%
img = Image.open(io.BytesIO(base64.b64decode(data)))

# %%
img.show()

# %%
data = "..."

# %%
import base64
import io
from PIL import Image
import cv2
       # Take in base64 string and return cv image
def stringToRGB(base64_string):
    imgdata = base64.b64decode(str(base64_string))
    dataBytesIO = io.BytesIO(imgdata)
    image = Image.open(dataBytesIO)
    return cv2.cvtColor(np.array(image), cv2.COLOR_BGR2RGB)

# %%
img = stringToRGB(data)

# %%
img.shape
# Out:
# (143, 266, 3)

# %%
Image.open()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-f303a75f88b6> in <module>
# ----> 1 Image.open('https://i.ytimg.com/vi/lY1vCa4rDyg/hqdefault.jpg?sqp=-oaymwEZCNACELwBSFXyq4qpAwsIARUAAIhCGAFwAQ==&rs=AOn4CLDnioFyHd5bLF7C7zFPwFjychg9pQ')
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2889
#    2890     if filename:
# -> 2891         fp = builtins.open(filename, "rb")
#    2892         exclusive_fp = True
#    2893
#
# OSError: [Errno 22] Invalid argument: 'https://i.ytimg.com/vi/lY1vCa4rDyg/hqdefault.jpg?sqp=-oaymwEZCNACELwBSFXyq4qpAwsIARUAAIhCGAFwAQ==&rs=AOn4CLDnioFyHd5bLF7C7zFPwFjychg9pQ'
