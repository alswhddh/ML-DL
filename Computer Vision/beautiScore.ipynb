# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import pandas as pd
import pickle

from keras.layers import Input, Activation, Conv2D, Flatten, Dense, MaxPooling2D, Dropout, Add, LeakyReLU
from keras.models import Model, load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint

import datetime
import os, sys, glob
plt.style.use('dark_background')

# %%
labels = pd.read_csv('/gdrive/MyDrive/beauty_score-master/train_test_files/All_labels.txt', sep=" ", header=None)
labels.head()
# Out:
#             0         1
# 0   CF437.jpg  2.883333
# 1  AM1384.jpg  2.466667
# 2  AM1234.jpg  2.150000
# 3  AM1774.jpg  3.750000
# 4   CF215.jpg  3.033333

# %%
labels_np = labels.values
print(labels_np[:5])
# Out:
# [['CF437.jpg' 2.8833330000000004]
#  ['AM1384.jpg' 2.4666669999999997]
#  ['AM1234.jpg' 2.15]
#  ['AM1774.jpg' 3.75]
#  ['CF215.jpg' 3.0333330000000003]]

# %%
imgs = np.empty((len(labels_np), 350, 350, 3), dtype=np.uint8)
no_load_idx = []
for i, (img_filename, rating) in enumerate(labels_np):
  try:
    img = cv2.imread(os.path.join('/gdrive/MyDrive/beauty_score-master/Images', img_filename))
    imgs[i] = img
  except:
    print(i,img_filename)
    no_load_idx.append(i)

# %%
x_train, x_val, y_train, y_val = train_test_split(imgs, labels_np[:, 1], test_size=0.1)
np.save('x_train.npy', x_train)
np.save('x_val.npy', x_val)
np.save('y_train.npy', y_train)
np.save('y_val.npy', y_val)
print(x_train.shape, x_val.shape)
print(y_train.shape, y_val.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-68b2e6f33673> in <module>()
# ----> 1 x_train, x_val, y_train, y_val = train_test_split(imgs, labels_np[:, 1], test_size=0.1)
#       2 np.save('x_train.npy', x_train)
#       3 np.save('x_val.npy', x_val)
#       4 np.save('y_train.npy', y_train)
#       5 np.save('y_val.npy', y_val)
#
# NameError: name 'train_test_split' is not defined

# %%
x_train = np.load('x_train.npy',allow_pickle=True)
y_train = np.load('y_train.npy',allow_pickle=True)
x_val = np.load('x_val.npy',allow_pickle=True)
y_val = np.load('y_val.npy',allow_pickle=True)

# %%
x_train = np.asarray(x_train).astype(np.float32) / 255
y_train= np.asarray(y_train).astype(np.float32)
x_val = np.asarray(x_val).astype(np.float32) / 255
y_val = np.asarray(y_val).astype(np.float32)

# %%
img = cv2.cvtColor(x_train[0], cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
plt.figure(figsize=(16, 6))
for i, img in enumerate(x_train[:10]):
    plt.subplot(2, 5, i+1)
    plt.axis('off')
    plt.title('%.2f' % y_train[i])
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img)

# %%
train_datagen = ImageDataGenerator(
#     rescale=1./255,
    rotation_range=30,
    shear_range=0.2,
    zoom_range=0.4,
    horizontal_flip=True
)

val_datagen = ImageDataGenerator(
#     rescale=1./255
)

train_generator = train_datagen.flow(
    x=x_train, y=y_train,
    batch_size=32,
    shuffle=True
)

val_generator = val_datagen.flow(
    x=x_val, y=y_val,
    batch_size=32,
    shuffle=False
)

# %%
augs = train_generator.__getitem__(8)

plt.figure(figsize=(16, 8))
for i, img in enumerate(augs[0]):
    plt.subplot(4, 8, i+1)
    plt.title('%.2f' % augs[1][i])
    plt.axis('off')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img.squeeze())

# %%
inputs = Input(shape=(350, 350, 3))

net = Conv2D(32, kernel_size=3, strides=1, padding='same')(inputs)
net = LeakyReLU()(net)
net = MaxPooling2D(pool_size=2)(net)

net = Conv2D(32, kernel_size=3, strides=1, padding='same')(net)
net = LeakyReLU()(net)
net = MaxPooling2D(pool_size=2)(net)

net = Conv2D(32, kernel_size=3, strides=1, padding='same')(net)
net = LeakyReLU()(net)
net = MaxPooling2D(pool_size=2)(net)

net = Conv2D(32, kernel_size=3, strides=1, padding='same')(net)
net = LeakyReLU()(net)
net = MaxPooling2D(pool_size=2)(net)

net = Conv2D(32, kernel_size=3, strides=1, padding='same')(net)
net = LeakyReLU()(net)
net = MaxPooling2D(pool_size=2)(net)

net = Flatten()(net)

net = Dense(256)(net)
net = Activation('relu')(net)
net = Dense(128)(net)
net = Activation('relu')(net)
net = Dense(1)(net)
outputs = Activation('linear')(net)

model = Model(inputs=inputs, outputs=outputs)

model.compile(optimizer='adam', loss='mae')

model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 350, 350, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 350, 350, 32)      896
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 350, 350, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 175, 175, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 175, 175, 32)      9248
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 175, 175, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 87, 87, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 87, 87, 32)        9248
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 87, 87, 32)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 43, 43, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 43, 43, 32)        9248
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 43, 43, 32)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 21, 21, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 21, 21, 32)        9248
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 21, 21, 32)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 10, 10, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 3200)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               819456
# _________________________________________________________________
# activation (Activation)      (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# activation_1 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# _________________________________________________________________
# activation_2 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 890,369
# Trainable params: 890,369
# Non-trainable params: 0
# _________________________________________________________________

# %%
start_time = datetime.datetime.now().strftime('%Y_%m_%d_%H_%M_%S')

model.fit_generator(
    train_generator, epochs=50, validation_data=val_generator,
    callbacks=[
        ModelCheckpoint('models/%s.h5' % (start_time), monitor='val_loss', save_best_only=True, mode='min', verbose=1)
    ]
)
# Out:
# WARNING:tensorflow:From <ipython-input-11-03f9b1461bf6>:6: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 155/155 [==============================] - ETA: 0s - loss: 0.6649
# Epoch 00001: val_loss improved from inf to 0.48135, saving model to models/2020_12_16_01_27_21.h5
# 155/155 [==============================] - 116s 752ms/step - loss: 0.6649 - val_loss: 0.4814
# Epoch 2/50
# 155/155 [==============================] - ETA: 0s - loss: 0.4983
# Epoch 00002: val_loss improved from 0.48135 to 0.47847, saving model to models/2020_12_16_01_27_21.h5
# 155/155 [==============================] - 119s 768ms/step - loss: 0.4983 - val_loss: 0.4785
# Epoch 3/50
# 155/155 [==============================] - ETA: 0s - loss: 0.4719
# Epoch 00003: val_loss improved from 0.47847 to 0.41823, saving model to models/2020_12_16_01_27_21.h5
# 155/155 [==============================] - 118s 762ms/step - loss: 0.4719 - val_loss: 0.4182
# Epoch 4/50
# 155/155 [==============================] - ETA: 0s - loss: 0.4488
# Epoch 00004: val_loss improved from 0.41823 to 0.38134, saving model to models/2020_12_16_01_27_21.h5
# 155/155 [==============================] - 118s 764ms/step - loss: 0.4488 - val_loss: 0.3813
# Epoch 5/50
# 155/155 [==============================] - ETA: 0s - loss: 0.4337
# Epoch 00005: val_loss did not improve from 0.38134
# 155/155 [==============================] - 118s 763ms/step - loss: 0.4337 - val_loss: 0.5018
# Epoch 6/50
# 155/155 [==============================] - ETA: 0s - loss: 0.4258
# Epoch 00006: val_loss did not improve from 0.38134
# 155/155 [==============================] - 118s 764ms/step - loss: 0.4258 - val_loss: 0.4039
# Epoch 7/50
# 155/155 [==============================] - ETA: 0s - loss: 0.4108
# Epoch 00007: val_loss improved from 0.38134 to 0.38076, saving model to models/2020_12_16_01_27_21.h5
# 155/155 [==============================] - 119s 766ms/step - loss: 0.4108 - val_loss: 0.3808
# Epoch 8/50
# 155/155 [==============================] - ETA: 0s - loss: 0.4028
# Epoch 00008: val_loss did not improve from 0.38076
# 155/155 [==============================] - 120s 771ms/step - loss: 0.4028 - val_loss: 0.4109
# Epoch 9/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3986
# Epoch 00009: val_loss improved from 0.38076 to 0.37023, saving model to models/2020_12_16_01_27_21.h5
# 155/155 [==============================] - 119s 769ms/step - loss: 0.3986 - val_loss: 0.3702
# Epoch 10/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3971
# Epoch 00010: val_loss did not improve from 0.37023
# 155/155 [==============================] - 119s 771ms/step - loss: 0.3971 - val_loss: 0.4242
# Epoch 11/50
# 155/155 [==============================] - ETA: 0s - loss: 0.4013
# Epoch 00011: val_loss did not improve from 0.37023
# 155/155 [==============================] - 120s 775ms/step - loss: 0.4013 - val_loss: 0.4842
# Epoch 12/50
# 155/155 [==============================] - ETA: 0s - loss: 0.4028
# Epoch 00012: val_loss did not improve from 0.37023
# 155/155 [==============================] - 120s 775ms/step - loss: 0.4028 - val_loss: 0.4127
# Epoch 13/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3747
# Epoch 00013: val_loss improved from 0.37023 to 0.33424, saving model to models/2020_12_16_01_27_21.h5
# 155/155 [==============================] - 120s 776ms/step - loss: 0.3747 - val_loss: 0.3342
# Epoch 14/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3761
# Epoch 00014: val_loss did not improve from 0.33424
# 155/155 [==============================] - 119s 771ms/step - loss: 0.3761 - val_loss: 0.3415
# Epoch 15/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3685
# Epoch 00015: val_loss did not improve from 0.33424
# 155/155 [==============================] - 120s 772ms/step - loss: 0.3685 - val_loss: 0.3709
# Epoch 16/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3734
# Epoch 00016: val_loss did not improve from 0.33424
# 155/155 [==============================] - 122s 784ms/step - loss: 0.3734 - val_loss: 0.3417
# Epoch 17/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3663
# Epoch 00017: val_loss did not improve from 0.33424
# 155/155 [==============================] - 122s 786ms/step - loss: 0.3663 - val_loss: 0.3476
# Epoch 18/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3730
# Epoch 00018: val_loss improved from 0.33424 to 0.31361, saving model to models/2020_12_16_01_27_21.h5
# 155/155 [==============================] - 122s 788ms/step - loss: 0.3730 - val_loss: 0.3136
# Epoch 19/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3686
# Epoch 00019: val_loss did not improve from 0.31361
# 155/155 [==============================] - 125s 806ms/step - loss: 0.3686 - val_loss: 0.3204
# Epoch 20/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3545
# Epoch 00020: val_loss improved from 0.31361 to 0.30976, saving model to models/2020_12_16_01_27_21.h5
# 155/155 [==============================] - 125s 806ms/step - loss: 0.3545 - val_loss: 0.3098
# Epoch 21/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3487
# Epoch 00021: val_loss did not improve from 0.30976
# 155/155 [==============================] - 125s 806ms/step - loss: 0.3487 - val_loss: 0.3612
# Epoch 22/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3519
# Epoch 00022: val_loss did not improve from 0.30976
# 155/155 [==============================] - 125s 805ms/step - loss: 0.3519 - val_loss: 0.3222
# Epoch 23/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3466
# Epoch 00023: val_loss improved from 0.30976 to 0.29780, saving model to models/2020_12_16_01_27_21.h5
# 155/155 [==============================] - 125s 805ms/step - loss: 0.3466 - val_loss: 0.2978
# Epoch 24/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3530
# Epoch 00024: val_loss did not improve from 0.29780
# 155/155 [==============================] - 125s 804ms/step - loss: 0.3530 - val_loss: 0.3071
# Epoch 25/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3479
# Epoch 00025: val_loss did not improve from 0.29780
# 155/155 [==============================] - 125s 803ms/step - loss: 0.3479 - val_loss: 0.2988
# Epoch 26/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3427
# Epoch 00026: val_loss did not improve from 0.29780
# 155/155 [==============================] - 125s 805ms/step - loss: 0.3427 - val_loss: 0.3118
# Epoch 27/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3394
# Epoch 00027: val_loss did not improve from 0.29780
# 155/155 [==============================] - 124s 803ms/step - loss: 0.3394 - val_loss: 0.3219
# Epoch 28/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3418
# Epoch 00028: val_loss did not improve from 0.29780
# 155/155 [==============================] - 125s 805ms/step - loss: 0.3418 - val_loss: 0.3075
# Epoch 29/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3331
# Epoch 00029: val_loss did not improve from 0.29780
# 155/155 [==============================] - 125s 807ms/step - loss: 0.3331 - val_loss: 0.3004
# Epoch 30/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3328
# Epoch 00030: val_loss did not improve from 0.29780
# 155/155 [==============================] - 125s 805ms/step - loss: 0.3328 - val_loss: 0.3340
# Epoch 31/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3382
# Epoch 00031: val_loss did not improve from 0.29780
# 155/155 [==============================] - 125s 805ms/step - loss: 0.3382 - val_loss: 0.3076
# Epoch 32/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3304
# Epoch 00032: val_loss improved from 0.29780 to 0.28544, saving model to models/2020_12_16_01_27_21.h5
# 155/155 [==============================] - 125s 805ms/step - loss: 0.3304 - val_loss: 0.2854
# Epoch 33/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3285
# Epoch 00033: val_loss did not improve from 0.28544
# 155/155 [==============================] - 126s 810ms/step - loss: 0.3285 - val_loss: 0.3039
# Epoch 34/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3305
# Epoch 00034: val_loss did not improve from 0.28544
# 155/155 [==============================] - 126s 811ms/step - loss: 0.3305 - val_loss: 0.4010
# Epoch 35/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3291
# Epoch 00035: val_loss did not improve from 0.28544
# 155/155 [==============================] - 126s 811ms/step - loss: 0.3291 - val_loss: 0.3268
# Epoch 36/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3274
# Epoch 00036: val_loss did not improve from 0.28544
# 155/155 [==============================] - 126s 810ms/step - loss: 0.3274 - val_loss: 0.2915
# Epoch 37/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3296
# Epoch 00037: val_loss improved from 0.28544 to 0.28438, saving model to models/2020_12_16_01_27_21.h5
# 155/155 [==============================] - 126s 811ms/step - loss: 0.3296 - val_loss: 0.2844
# Epoch 38/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3299
# Epoch 00038: val_loss did not improve from 0.28438
# 155/155 [==============================] - 127s 818ms/step - loss: 0.3299 - val_loss: 0.3435
# Epoch 39/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3265
# Epoch 00039: val_loss improved from 0.28438 to 0.28323, saving model to models/2020_12_16_01_27_21.h5
# 155/155 [==============================] - 127s 822ms/step - loss: 0.3265 - val_loss: 0.2832
# Epoch 40/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3150
# Epoch 00040: val_loss did not improve from 0.28323
# 155/155 [==============================] - 127s 822ms/step - loss: 0.3150 - val_loss: 0.2919
# Epoch 41/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3194
# Epoch 00041: val_loss did not improve from 0.28323
# 155/155 [==============================] - 128s 827ms/step - loss: 0.3194 - val_loss: 0.2989
# Epoch 42/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3166
# Epoch 00042: val_loss did not improve from 0.28323
# 155/155 [==============================] - 128s 826ms/step - loss: 0.3166 - val_loss: 0.2895
# Epoch 43/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3224
# Epoch 00043: val_loss did not improve from 0.28323
# 155/155 [==============================] - 128s 829ms/step - loss: 0.3224 - val_loss: 0.2839
# Epoch 44/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3187
# Epoch 00044: val_loss did not improve from 0.28323
# 155/155 [==============================] - 128s 828ms/step - loss: 0.3187 - val_loss: 0.2898
# Epoch 45/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3130
# Epoch 00045: val_loss improved from 0.28323 to 0.27884, saving model to models/2020_12_16_01_27_21.h5
# 155/155 [==============================] - 129s 831ms/step - loss: 0.3130 - val_loss: 0.2788
# Epoch 46/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3158
# Epoch 00046: val_loss did not improve from 0.27884
# 155/155 [==============================] - 129s 832ms/step - loss: 0.3158 - val_loss: 0.3010
# Epoch 47/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3186
# Epoch 00047: val_loss did not improve from 0.27884
# 155/155 [==============================] - 128s 828ms/step - loss: 0.3186 - val_loss: 0.2822
# Epoch 48/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3145
# Epoch 00048: val_loss did not improve from 0.27884
# 155/155 [==============================] - 129s 831ms/step - loss: 0.3145 - val_loss: 0.2854
# Epoch 49/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3093
# Epoch 00049: val_loss did not improve from 0.27884
# 155/155 [==============================] - 128s 829ms/step - loss: 0.3093 - val_loss: 0.3106
# Epoch 50/50
# 155/155 [==============================] - ETA: 0s - loss: 0.3068
# Epoch 00050: val_loss did not improve from 0.27884
# 155/155 [==============================] - 128s 828ms/step - loss: 0.3068 - val_loss: 0.2895

# %%
model = load_model('models/2020_12_16_01_27_21.h5')

val_data = val_generator.__getitem__(1)

preds = model.predict(val_data[0])

plt.figure(figsize=(16, 8))
for i, img in enumerate(val_data[0]):
    plt.subplot(4, 8, i+1)
    plt.title('%.2f / %.2f' % (preds[i], val_data[1][i]))
    plt.axis('off')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img.squeeze())

# %%
img_test_list = glob.glob('/gdrive/MyDrive/beauty_score-master/img/*.jpg')

imgs_test_resized = []

plt.figure(figsize=(16, 8))
for i, img_path in enumerate(img_test_list):
    img = cv2.imread(img_path)
    img_resized = cv2.resize(img, (350, 350))

    plt.subplot(1, len(img_test_list), i+1)
    plt.axis('off')
    img = cv2.cvtColor(img_resized, cv2.COLOR_BGR2RGB)
    plt.imshow(img.squeeze())
    
    img_resized = img_resized.astype(np.float32) / 255.
    imgs_test_resized.append(img_resized)

imgs_test_resized = np.array(imgs_test_resized, dtype=np.float32)

# %%
preds = model.predict(imgs_test_resized)

plt.figure(figsize=(16, 8))
for i, img in enumerate(imgs_test_resized):
    plt.subplot(1, len(imgs_test_resized), i+1)
    plt.title('%.2f' % (preds[i]))
    plt.axis('off')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img.squeeze())
